# %% [markdown]
# # formata-texto
# Esse script recebe arquivos .txt extraídos do site da Câmara dos Deputados e executa operações de limpeza e formatação usando regex.

# %% [markdown]
# #### Importação de pacotes

# %%
#!pip install unidecode

# %%
import glob
import os
import pandas as pd
import re
from unidecode import unidecode

import os
import zipfile
import io

import random

# %%
# VARIÁVEL GLOBAL PARA TESTAR VÁRIOS ENCODINGS
encoding = 'UTF-8'

# %% [markdown]
# #### Ler arquivos externos

# %%
def find_fpaths(dir_path, pattern):
    '''
    >> DESCRIÇÃO
    
    Usa o módulo glob para buscar todos os arquivos
    que correspondam ao padrão passado na variável 
    pattern'. Retorna uma lista de paths no formato 
    string. 
    
    >> PARÂMETROS
    
    dir_path -> uma string com o caminho para o
    diretório onde a busca pelos arquivos será
    realizada.
    
    pattern -> uma string com o padrão de texto
    que deve ser procurado no diretório.
    
    '''
    
    full_pattern = dir_path + pattern
    files = glob.glob(full_pattern)
    return files

# %%
def read_file(file_list, zip_file = False):
    random.seed(2020)
    '''
    >> DESCRIÇÃO
    
    Lê a lista de arquivos e configura o conteúdo
    em um dataframe com os seguintes campos:
    PRESIDENTE | CONTEUDO | ARQUIVO | ANO
    Funciona para os discursos em plenário
    
    >> PARÂMETROS
    
    file_list -> uma lista de filepaths em formato
    string. Ela é gerada anteriormente, na função
    find_fpaths.
    
    '''
    print('Reading Files...')
    content = []
    name_file_list = []
    if zip_file:
        for f in file_list:#[:5]:
            #print('-->',f)
            with zipfile.ZipFile(f) as zip_file:
                print(f, len(zip_file.filelist))
                ## serão selecionados 30% do total de cada arquivo de forma aleatória
                sample_size = round(len(zip_file.filelist)*.3)
                for name_file in random.sample(zip_file.filelist,sample_size):
                    name_file_list.append(unidecode(name_file.filename))
                    
                    with io.TextIOWrapper(zip_file.open(name_file.filename), encoding=encoding) as arq:
                        content.append(arq.read())

    else:
        # Lê o conteúdo dos arquivos de texto na lista
        content = [ open(file, encoding = encoding).read() for file in file_list ]
        name_file_list = [ unidecode(file) for file in file_list ]

    return content, name_file_list

def make_df_plen(file_list, content):
    print('Making  DF plen...')
    session_date = []
    for file in info:
        result = re.search("\-([A-Z\s]+)\-", file)# info[108251])
        if result is None:
            session_date.append('none')
        else:
            session_date.append(result.group(1))
        
    # Transforma eum dataframe
    df = pd.DataFrame({
        'FILE'             : [ file for file in content ],
        'ORIGINAL_CONTENT' : [ item for item in file_list ],
        'CLEAN_CONTENT'    : [ unidecode(item) for item in file_list ],
        'SESSION_TYPE'     : session_date,#[ re.search("\-([A-Z\s]+)\-", file).group(1) for file in content ],
        'SESSION_DATE'     : [ re.search("\d{8}", file).group(0) for file in content ]
    })
    
    df["SESSION_DATE"] = pd.to_datetime(df.SESSION_DATE, format = "%d%m%Y")
    df["MONTH"] = df.SESSION_DATE.dt.month
    df["YEAR"] = df.SESSION_DATE.dt.year

    return df

# %% [markdown]
# #### Funções de formatação e busca usando regex

# %%
def find_speakers(string):
    
    '''
    Essa função detecta o padrão de texto
    que antecede a fala de um deputado e
    retorna um objeto match (via re.find_all).
    Ele é útil para detectar QUANTOS deputados
    falaram em determinada string textual.
    '''
    
    pattern = "((O?\s?SR\.?\s+?)|(A?\s?SRA\.?\s+?))(\s+DEPUTADO|\s+DEPUTADA|\s+PRESIDENTE|\s+PRESIDENTA)?"
    regexp = re.compile(pattern)
    matches = re.findall(regexp, string)
    
    return matches

# %%
def extract_full_quote(clean_string, original_string):
    
    '''
    Essa função extrai todas as falas de Jair Bolsonaro
    em uma determinada string. O pattern de regex encontra,
    primeiro, uma fala qualquer do Presidente. Então, pega
    tudo que está entre essa fala e a fala de outro parlamentar 
    ou o fim do arquivo. Isso é necessário porque há arquivos
    que misturam a fala de vários parlamentares, geralmente
    quando estão envolvidos em uma discussão.
    
    Para fazer essa operação, são passados textos sem caracteres
    especiais unicode. Depois de feita a captura, usamos os índices
    das matches no regex para extrair o mesmo pedaço de texto
    na string original.

    '''
    
    #if "O SR. PRESIDENTE (Jair Bolsonaro)" in clean_string:
     #   pattern = "O SR\. PRESIDENTE (\(Jair Bolsonaro\))?(.*?)((O?\s?SR\.?\s+?)|(A?\s?SRA\.?\s+?)|$)"
      #  group_no = 2

    #else:
    #pattern  = "O?\s?SR\.?\s?(DEPUTADO)?\s+JAIR\s+BOLSONARO\s?(\((Bloco\/)?\w{2,}\s?\-\s?\w{2}[^)]+\))?(.*?)((O?\s?SR\.?\s+?)|(A?\s?SRA\.?\s+?)|$)"
    pattern = "((O?\s?SR\.?\s+?)|(A?\s?SRA\.?\s+?))(\s+DEPUTADO|\s+DEPUTADA|\s+PRESIDENTE|\s+PRESIDENTA)?"
    group_no = 4
        
    regexp   = re.compile(pattern, re.MULTILINE)
    matches  = re.finditer(regexp, clean_string)
    
    full_clean_quote    = [ ]
    full_original_quote = [ ]
    
    for match in matches:
                        
        match_start = match.start(group_no)
        match_end   = match.end(group_no)
            
        clean_quote = match[group_no]
        clean_quote = clean_quote.replace("- ", "")
        
        original_quote = original_string[match_start:match_end]
        original_quote = original_quote.replace("- ", "")
        
        full_clean_quote.append(clean_quote)
        full_original_quote.append(original_quote)
        
    full_clean_quote    = ' [ INTERRUPÇÃO ] '.join(full_clean_quote)
    full_original_quote = ' [ INTERRUPÇÃO ] '.join(full_original_quote)

    # Remove espaços múltiplos internos usando a operação join de lista
    full_clean_quote    = ' '.join(full_clean_quote.split()) 
    full_original_quote = ' '.join(full_original_quote.split()) 
    
    return full_clean_quote, full_original_quote

# %% [markdown]
# #### Funções para aplicar operações de regex no dataframe

# %%
def apply_count_speakers(row):
    
    '''
    Aplica, linha a linha, a função
    find_speakers(string)
    '''
    
    matches = find_speakers(row.CLEAN_CONTENT)
    speaker_count = len(matches)
    
    return pd.Series({ "SPEAKER_COUNT":speaker_count 
        })

# %%
def apply_extract_full_quote(row):
    
    '''
    Aplica, linha a linha, a função
    extract_full_quote(string)
    '''
    
    full_clean_quote, full_original_quote = extract_full_quote(row.CLEAN_CONTENT, row.ORIGINAL_CONTENT)
    return pd.Series({
        "FULL_CLEAN_QUOTE"    : full_clean_quote,
        "FULL_ORIGINAL_QUOTE" : full_original_quote
    })

# %% [markdown]
# #### Função que encapsula anteriores e roda a operação

# %%
def get_speak(zip_file = False):
    '''
    zip_file -> indica se os arquivos estão compactados no formato ZIP.
    
    Executa as operações anteriores em ambos os bancos de dados
    (plenário e comissões), filtra entradas sem match, concatena
    ambos os dataframes e salva para arquivo csv.
    '''
    list_info_file = []
    list_speak = []
    
    if zip_file:
        #list_speak, list_info_file = read_file( find_fpaths("../data/txts/plenario/", "*.zip"), zip_file)
        list_speak, list_info_file = read_file( find_fpaths("/disco01/gabriel/plenario/", "*.zip"), zip_file)
    else:
        list_speak, list_info_file = read_file(find_fpaths("../data/txts/plenario/", "*.txt"),zip_file)
        
    
    return list_speak, list_info_file

# %%
def get_metadata(year = None):
    if year:
        metadata = pd.read_csv(path+'plenario/tables/{}-plenario-metadata.csv'.format(year))
        #print(metadata.shape)
        return metadata
    return None

# %%
## LENDO OS DISCURSOS E SALVANDO EM UM DATAFRAME
path = '/disco01/gabriel/'
speak, info = get_speak(True)
# Out:
# Reading Files...
# /disco01/gabriel/plenario/2001.zip 19355
# /disco01/gabriel/plenario/2005.zip 20185
# /disco01/gabriel/plenario/2012.zip 20031
# /disco01/gabriel/plenario/2002.zip 10353
# /disco01/gabriel/plenario/2013.zip 27752
# /disco01/gabriel/plenario/2014.zip 17303
# /disco01/gabriel/plenario/2010.zip 14961
# /disco01/gabriel/plenario/2003.zip 23829
# /disco01/gabriel/plenario/2016.zip 23092
# /disco01/gabriel/plenario/2019.zip 19506
# /disco01/gabriel/plenario/2017.zip 28134
# /disco01/gabriel/plenario/2018.zip 16560
# /disco01/gabriel/plenario/2009.zip 24499
# /disco01/gabriel/plenario/2011.zip 22727
# /disco01/gabriel/plenario/2008.zip 20488
# /disco01/gabriel/plenario/2007.zip 25116
# /disco01/gabriel/plenario/2006.zip 15522
# /disco01/gabriel/plenario/2015.zip 28169
# /disco01/gabriel/plenario/2004.zip 19028

# %%
i = 5
#speak[i],info[i]

# %%
df_plen = make_df_plen(speak,info)
#df_plen['INFO'] = info

#As sessões do tipo HOMENAGEM são apenas registro de protocolo. 
#Não contém transcrição de discursos.
df_plen = df_plen[ df_plen.SESSION_TYPE != "HOMENAGEM" ]

# Aplica funções para extrair discursos
df_plen["SPEAKER_COUNT"] = df_plen.apply(apply_count_speakers, axis=1)
df_plen.index = [i for i in range(len(df_plen))]

#return df_plen
# Out:
# Making  DF plen...

# %%
len(df_plen)
# Out:
# 113143

# %%
## inserindo metadados no data frame dos discursos
df_metadata = pd.DataFrame()
for y in df_plen.YEAR.unique():
    print(y)
    metadata = get_metadata(y)
    #if metadata != None:
    for f in df_plen.loc[df_plen.YEAR == y,'FILE'].apply(lambda x: x.split('-')[0]):
        f = int(f)
        df_metadata = pd.concat([df_metadata,metadata.loc[f:f,['Orador','Hora']]])

df_metadata.index = [i for i in range(len(df_metadata))]

df_plen = pd.concat([df_plen,df_metadata],axis=1)
print('Finalizado...')
# Out:
# 2001
# 2005
# 2012
# 2002
# 2013
# 2014
# 2010
# 2018
# 2003
# 2016
# 2019
# 2017
# 2009
# 2011
# 2008
# 2007
# 2006
# 2015
# 2004

# %%
df_plen.head(20)

# %%
orador = []
partido = []
ufPartido = []

for i,d in enumerate(df_plen.Orador):#[0].split('-')
    splitOrador  = d.split(',')
    #print(i,d,splitOrador)
    
    if len(splitOrador) > 1:
        splitPartido = splitOrador[1].split('-')
        
        if len(splitPartido) < 2:
            partido.append('N/I')
            ufPartido.append('N/I')
        else:
            partido.append(splitPartido[0])
            ufPartido.append(splitPartido[1])
    else:
        splitPartido = splitOrador[0].split('-')
        partido.append('N/I')
        ufPartido.append('N/I')
    
    orador.append(splitOrador[0])
    if len(splitPartido) < 2 or len(splitPartido) > 2:
        print(d,splitPartido)
    
print('Finalizado...')
# Out:
# ROBERTO LEHER(PRESIDENTE DO SINDICATO NACIONAL DOS DOCENTES DAS INSTITUIÇÕES DE ENSINO SUPERIOR) ['ROBERTO LEHER(PRESIDENTE DO SINDICATO NACIONAL DOS DOCENTES DAS INSTITUIÇÕES DE ENSINO SUPERIOR)']
# NIVALDO SANTANA (DEPUTADO ESTADUAL DE SÃO PAULO, SP) [' SP)']
# FRANCISCO ALMEIDA FILHO (DIRETOR DO DEPARTAMENTO DO PATRIMÔNIO HISTÓRICO E ARTÍSTICO DE BRASÍLIA) ['FRANCISCO ALMEIDA FILHO (DIRETOR DO DEPARTAMENTO DO PATRIMÔNIO HISTÓRICO E ARTÍSTICO DE BRASÍLIA)']
# GERMANO LAMBERT TORRES(PRÓ-DIRETOR DE PESQUISA E PÓS-GRADUAÇÃO DA ESCOLA FEDERAL DE ENGENHARIA DE ITAJUBÁ) ['GERMANO LAMBERT TORRES(PRÓ', 'DIRETOR DE PESQUISA E PÓS', 'GRADUAÇÃO DA ESCOLA FEDERAL DE ENGENHARIA DE ITAJUBÁ)']
# JOÃO CARLOS CASCAIS(REPRESENTANTE DO CONSELHO REGIONAL DE ENGENHARIA E ARQUITETURA DO PARANÁ) ['JOÃO CARLOS CASCAIS(REPRESENTANTE DO CONSELHO REGIONAL DE ENGENHARIA E ARQUITETURA DO PARANÁ)']
# AÉCIO NEVES (PRESIDENTE) ['AÉCIO NEVES (PRESIDENTE)']
# DANTE ALARIO JUNIOR ( REPRESENTANTE DO BIOLAB) ['DANTE ALARIO JUNIOR ( REPRESENTANTE DO BIOLAB)']
# HILDA RODRIGUES DO TANQUE(PRESIDENTE DO CONSELHO DELIBERATIVO DA ASSOCIAÇÃO DOS PROFESSORES APOSENTADOS DO MAGISTÉRIO PÚBLICO DO ESTADO DE SÃO PAULO) ['HILDA RODRIGUES DO TANQUE(PRESIDENTE DO CONSELHO DELIBERATIVO DA ASSOCIAÇÃO DOS PROFESSORES APOSENTADOS DO MAGISTÉRIO PÚBLICO DO ESTADO DE SÃO PAULO)']
# ANTONIO CARLOS FONSECA (PROFESSOR DE DIREITO ECONÔMICO DA UNB) ['ANTONIO CARLOS FONSECA (PROFESSOR DE DIREITO ECONÔMICO DA UNB)']
# PAULO RIKBAKTSA - (REPRESENTANTE DA REGIÃO CENTRO-OESTE) ['PAULO RIKBAKTSA ', ' (REPRESENTANTE DA REGIÃO CENTRO', 'OESTE)']
# SÍLVIO ALEIXO(REPRESENTANTE DO SECRETÁRIO DE ENERGIA DO ESTADO DE SÃO PAULO, E DO PRESIDENTE DA CTEEP) [' E DO PRESIDENTE DA CTEEP)']
# EGLER MARCELINO DOS SANTOS(DIRETOR DA ASSUFEMG) ['EGLER MARCELINO DOS SANTOS(DIRETOR DA ASSUFEMG)']
# EVILASIO XAVANTE (MEMBRO DA CONFEDERAÇÃO NACIONAL DO POVO XAVANTE) ['EVILASIO XAVANTE (MEMBRO DA CONFEDERAÇÃO NACIONAL DO POVO XAVANTE)']
# JOSÉ ANTÔNIO ZEM (SUPERINTENDENTE DA SECRETARIA EXTRAORDINÁRIA DE ASSUNTOS METROPOLITANOS) ['JOSÉ ANTÔNIO ZEM (SUPERINTENDENTE DA SECRETARIA EXTRAORDINÁRIA DE ASSUNTOS METROPOLITANOS)']
# LUIZ GONZAGA ULHÔA TENÓRIO(DIRETOR DA FEDERAÇÃO NACIONAL DOS URBANITÁRIOS) ['LUIZ GONZAGA ULHÔA TENÓRIO(DIRETOR DA FEDERAÇÃO NACIONAL DOS URBANITÁRIOS)']
# VLADIMIR NEPOMUCENO(DIRETOR DA CONFEDERAÇÃO DOS TRABALHADORES EM SEGURIDADE SOCIAL) ['VLADIMIR NEPOMUCENO(DIRETOR DA CONFEDERAÇÃO DOS TRABALHADORES EM SEGURIDADE SOCIAL)']
# ROBERTO VÍCTOR DE ALMEIDA (PRESIDENTE) (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE ANGOLA). ['ROBERTO VÍCTOR DE ALMEIDA (PRESIDENTE) (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE ANGOLA).']
# MARIA ELISA LADEIRA- REPRESENTANTE DO  CENTRO DE TRABALHO INDIGENISTA - CTI. ['MARIA ELISA LADEIRA', ' REPRESENTANTE DO  CENTRO DE TRABALHO INDIGENISTA ', ' CTI.']
# TERESA COHEN (DEPUTADA DA ASSEMBLÉIA NACIONAL DE ANGOLA ) ['TERESA COHEN (DEPUTADA DA ASSEMBLÉIA NACIONAL DE ANGOLA )']
# MANUEL BRITO SEMEDO ( DIRETOR-EXECUTIVO DO INSTITUTO INTERNACIONAL DE LÍNGUA PORTUGUESA - IILP) ['MANUEL BRITO SEMEDO ( DIRETOR', 'EXECUTIVO DO INSTITUTO INTERNACIONAL DE LÍNGUA PORTUGUESA ', ' IILP)']
# VÍTOR RAMALHO (DEPUTADO DA ASSEMBLÉIA DA REÚBLICA DE PORTUGAL) ['VÍTOR RAMALHO (DEPUTADO DA ASSEMBLÉIA DA REÚBLICA DE PORTUGAL)']
# MANUEL BRITO SEMEDO ( DIRETOR-EXECUTIVO DO INSTITUTO INTERNACIONAL DE LÍNGUA PORTUGUESA - IILP) ['MANUEL BRITO SEMEDO ( DIRETOR', 'EXECUTIVO DO INSTITUTO INTERNACIONAL DE LÍNGUA PORTUGUESA ', ' IILP)']
# FRANCISCO BENANTE - (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR - ANP- GUINÉ-BISSAU). ['FRANCISCO BENANTE ', ' (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR ', ' ANP', ' GUINÉ', 'BISSAU).']
# CARLOS FERNANDES ['CARLOS FERNANDES']
# JOSÉ MIGUEL ANACORETA CORREIA (DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORUTUGAL) ['JOSÉ MIGUEL ANACORETA CORREIA (DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORUTUGAL)']
# LUÍS FONSECA (EMBAIXADOR -  SECRETÁRIO-EXECUTIVO DA COMUNIDADE DOS PAÍSES DE LÍNGUA PORTUGUESA). ['LUÍS FONSECA (EMBAIXADOR ', '  SECRETÁRIO', 'EXECUTIVO DA COMUNIDADE DOS PAÍSES DE LÍNGUA PORTUGUESA).']
# FRANCISCO GUETERRES "LÚ-OLO" -  (PRESIDENTE DO PARLAMENTO NACIONAL DE TIMOR-LESTE) ['FRANCISCO GUETERRES "LÚ', 'OLO" ', '  (PRESIDENTE DO PARLAMENTO NACIONAL DE TIMOR', 'LESTE)']
# ARISTIDES RAIMUNDO LIMA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE). ['ARISTIDES RAIMUNDO LIMA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE).']
# FRANCISCO BENANTE - (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR - ANP- GUINÉ-BISSAU). ['FRANCISCO BENANTE ', ' (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR ', ' ANP', ' GUINÉ', 'BISSAU).']
# ROBERTO VÍCTOR DE ALMEIDA (PRESIDENTE) (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE ANGOLA). ['ROBERTO VÍCTOR DE ALMEIDA (PRESIDENTE) (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE ANGOLA).']
# DANILO AFONSO-  COMUNIDADE INDÍGENA MONTE MORIÁ II, DE UIRAMUTÃ, ESTADO DE RORAIMA. [' DE UIRAMUTÃ']
# GUILHERME POSSER DA COSTA (DEPUTADO DO PARLAMENTO NACIONAL DE SÃO TOMÉ E PRINCIPE) ['GUILHERME POSSER DA COSTA (DEPUTADO DO PARLAMENTO NACIONAL DE SÃO TOMÉ E PRINCIPE)']
# CÉLINE HERVIEUX-PAYETTESENADORA - PRESIDENTA DO FÓRUM INTERPARLAMENTAR DAS AMÉRICAS. ['CÉLINE HERVIEUX', 'PAYETTESENADORA ', ' PRESIDENTA DO FÓRUM INTERPARLAMENTAR DAS AMÉRICAS.']
# HONÓRIO BRITO (DEPUTADO DA ASSEMBLÉIA NACIONAL DE CABO VERDE) ['HONÓRIO BRITO (DEPUTADO DA ASSEMBLÉIA NACIONAL DE CABO VERDE)']
# JOSEP BORRELL FONTELLES ['JOSEP BORRELL FONTELLES']
# FRANCISCO BENANTE (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR - ANP- GUINÉ-BISSAU). ['FRANCISCO BENANTE (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR ', ' ANP', ' GUINÉ', 'BISSAU).']
# ORLANDA FERREIRA (DEPUTADA DA ASSEMBLÉIA NACIONAL DE CABO VERDE) ['ORLANDA FERREIRA (DEPUTADA DA ASSEMBLÉIA NACIONAL DE CABO VERDE)']
# VÍTOR RAMALHO (DEPUTADO DA ASSEMBLÉIA DA REÚBLICA DE PORTUGAL) ['VÍTOR RAMALHO (DEPUTADO DA ASSEMBLÉIA DA REÚBLICA DE PORTUGAL)']
# FRANCISCO BENANTE - (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR - ANP- GUINÉ-BISSAU). ['FRANCISCO BENANTE ', ' (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR ', ' ANP', ' GUINÉ', 'BISSAU).']
# ALBERTINO BRAGANÇA (DEPUTADO DA ASSEMBLÉIA NACIONAL DE SÃO TOMÉ E PRÍNCIPE). ['ALBERTINO BRAGANÇA (DEPUTADO DA ASSEMBLÉIA NACIONAL DE SÃO TOMÉ E PRÍNCIPE).']
# ANTÔNIO PINHEIRO TORRES (DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORTUGAL) ['ANTÔNIO PINHEIRO TORRES (DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORTUGAL)']
# TERESA COHEN (DEPUTADA DA ASSEMBLÉIA NACIONAL DE ANGOLA) ['TERESA COHEN (DEPUTADA DA ASSEMBLÉIA NACIONAL DE ANGOLA)']
# LUIZ VIEIRA TITIAH- PATAXÓ HÃ HÃ HÃE, MEMBRO DA ARTICULAÇÃO DOS POVOS INDÍGENAS DO NORDESTE, MINAS GERAIS E ESPÍRITO SANTO - APOINME. [' MEMBRO DA ARTICULAÇÃO DOS POVOS INDÍGENAS DO NORDESTE']
# SEVERINO CAVALCANTI (PRESIDENTE DA CÂMARA DOS DEPUTADOS) ['SEVERINO CAVALCANTI (PRESIDENTE DA CÂMARA DOS DEPUTADOS)']
# ALBERTINO BRAGANÇA  (DEPUTADO DA ASSEMBLÉIA NACIONAL DE SÃO TOMÉ E PRÍNCIPE) ['ALBERTINO BRAGANÇA  (DEPUTADO DA ASSEMBLÉIA NACIONAL DE SÃO TOMÉ E PRÍNCIPE)']
# ORLANDA FERREIRA (DEPUTADA DA ASSEMBLÉIA NACIONAL DE CABO VERDE) ['ORLANDA FERREIRA (DEPUTADA DA ASSEMBLÉIA NACIONAL DE CABO VERDE)']
# JECINALDO BARBOSA CABRAL- COORDENADOR-GERAL DA COORDENAÇÃO DAS ORGANIZAÇÕES INDÍGENAS DA AMAZÔNIA BRASILEIRA - COIAB. ['JECINALDO BARBOSA CABRAL', ' COORDENADOR', 'GERAL DA COORDENAÇÃO DAS ORGANIZAÇÕES INDÍGENAS DA AMAZÔNIA BRASILEIRA ', ' COIAB.']
# VÍTOR RAMALHO (DEPUTADO DA ASSEMBLÉIA DA REÚBLICA DE PORTUGAL) ['VÍTOR RAMALHO (DEPUTADO DA ASSEMBLÉIA DA REÚBLICA DE PORTUGAL)']
# JOSÉ MIGUEL ANACORETA CORREIA (DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORUTUGAL) ['JOSÉ MIGUEL ANACORETA CORREIA (DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORUTUGAL)']
# ARISTIDES RAIMUNDO LIRA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE) ['ARISTIDES RAIMUNDO LIRA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE)']
# VÍTOR RAMALHO ( DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORTUGAL) ['VÍTOR RAMALHO ( DEPUTADO DA ASSEMBLÉIA DA REPÚBLICA DE PORTUGAL)']
# EUGÊNIO MANUVAKOLA (DEPUTADO DA ASSEMBLÉIA NACIONAL DE ANGOLA) ['EUGÊNIO MANUVAKOLA (DEPUTADO DA ASSEMBLÉIA NACIONAL DE ANGOLA)']
# FRANCISCO BENANTE - (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR - ANP- GUINÉ-BISSAU). ['FRANCISCO BENANTE ', ' (PRESIDENTE DA ASSEMBLEIA NACIONAL POPULAR ', ' ANP', ' GUINÉ', 'BISSAU).']
# JOÃO PAULO CUNHA (PRESIDENTE DA CÂMARA DOS DEPUTADOS) ['JOÃO PAULO CUNHA (PRESIDENTE DA CÂMARA DOS DEPUTADOS)']
# ROBERTO VICTOR DE ALMEIDA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE ANGOLA). ['ROBERTO VICTOR DE ALMEIDA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE ANGOLA).']
# ESPER CAVALHEIRO- REPRESENTANDO O DR. EDUARDO KRIEGER, DA ACADEMIA BRASILEIRA DE CIÊNCIAS. [' DA ACADEMIA BRASILEIRA DE CIÊNCIAS.']
# ROBERTO VICTOR DE ALMEIDA ( DEPUTADO DA ASSEMBLÉIA NACIONAL DE ANGOLA) ['ROBERTO VICTOR DE ALMEIDA ( DEPUTADO DA ASSEMBLÉIA NACIONAL DE ANGOLA)']
# LOURDES MARIA ALVES (DEPUTADA DO PARLAMENTO NACIONAL DA REPÚBLICA DEMOCRÁTICA DO TIMOR LESTE) ['LOURDES MARIA ALVES (DEPUTADA DO PARLAMENTO NACIONAL DA REPÚBLICA DEMOCRÁTICA DO TIMOR LESTE)']
# LUIZ CARLOS HAULY- REPRESENTANTE BRASILEIRO NO FÓRUM INTERPARLAMENTAR DAS AMÉRICAS - FIPA. ['LUIZ CARLOS HAULY', ' REPRESENTANTE BRASILEIRO NO FÓRUM INTERPARLAMENTAR DAS AMÉRICAS ', ' FIPA.']
# ARISTIDES RAIMUNDO LIMA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE). ['ARISTIDES RAIMUNDO LIMA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE).']
# SAULO FERREIRA FEITOSA- VICE-PRESIDENTE DO CONSELHO INDIGENISTA MISSIONÁRIO - CIMI ['SAULO FERREIRA FEITOSA', ' VICE', 'PRESIDENTE DO CONSELHO INDIGENISTA MISSIONÁRIO ', ' CIMI']
# ARISTIDES RAIMUNDO LIMA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE). ['ARISTIDES RAIMUNDO LIMA (PRESIDENTE DA ASSEMBLÉIA NACIONAL DE CABO VERDE).']
# LUIZ SÉRGIO ['LUIZ SÉRGIO']
# DANIELA ZORZIN DE CARVALHO , PARLAMENTAR JOVEM [' PARLAMENTAR JOVEM']
# FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL) ['FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL)']
# FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL) ['FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL)']
# FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL) ['FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL)']
# FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL) ['FERNANDO BEZERRA(MINISTRO DE ESTADO DA INTEGRAÇÃO NACIONAL)']
# CLÁUDIO AUGUSTO VIEIRA DA SILVA PRESIDENTE DO CONSELHO NACIONAL DOS DIREITOS DA CRIANÇA E DO ADOLESCENTE; ['CLÁUDIO AUGUSTO VIEIRA DA SILVA PRESIDENTE DO CONSELHO NACIONAL DOS DIREITOS DA CRIANÇA E DO ADOLESCENTE;']
# MARLOVA NOLETO  REPRESENTANTE DA ORGANIZAÇÃO DAS NAÇÕES UNIDAS PARA A EDUCAÇÃO, CIÊNCIA E CULTURA; [' CIÊNCIA E CULTURA;']
# LADISLAU MARTIN NETO - DIRETOR-EXECUTIVO DE PESQUISA & DESENVOLVIMENTO DA EMPRESA BRASILEIRA DE PESQUISA AGROPECUÁRIA - EMBRAPA. ['LADISLAU MARTIN NETO ', ' DIRETOR', 'EXECUTIVO DE PESQUISA & DESENVOLVIMENTO DA EMPRESA BRASILEIRA DE PESQUISA AGROPECUÁRIA ', ' EMBRAPA.']
# ALESSANDRO CÂMARA DE SOUZA, ASSESSOR DA COORDENADORIA MUNICIPAL DE ACESSIBILIDADE E CIDADANIA DE NITERÓI, ESTADO DO RIO DE JANEIRO [' ASSESSOR DA COORDENADORIA MUNICIPAL DE ACESSIBILIDADE E CIDADANIA DE NITERÓI']
# DENISE ASSUMPÇÃO FERNANDES, PRESIDENTE NACIONAL DO PSC MULHER. [' PRESIDENTE NACIONAL DO PSC MULHER.']
# WALTER WANDERLEY DE PAULA PENA - DIRETOR-SUPERINTENDENTE DO DEPARTAMENTO DE TRÂNSITO - DETRAN DO ESTADO DO PARÁ, REPRESENTANTE DA ASSOCIAÇÃO NACIONAL DOS DEPARTAMENTOS DE TRÂNSITO. [' REPRESENTANTE DA ASSOCIAÇÃO NACIONAL DOS DEPARTAMENTOS DE TRÂNSITO.']
# EVERTON OCTAVIANI, PREFEITO MUNICIPAL DE AGUDOS, ESTADO DE SÃO PAULO [' PREFEITO MUNICIPAL DE AGUDOS']
# GIUSEPPE MARRARA, DIRETOR DE RELAÇÕES GOVERNAMENTAIS DA CISCO SYSTEMS [' DIRETOR DE RELAÇÕES GOVERNAMENTAIS DA CISCO SYSTEMS']
# CARLOS VITAL TAVARES CORRÊA- 1º VICE-PRESIDENTE DO CONSELHO FEDERAL DE MEDICINA. ['CARLOS VITAL TAVARES CORRÊA', ' 1º VICE', 'PRESIDENTE DO CONSELHO FEDERAL DE MEDICINA.']
# DEMI GETSCHKO-COMITÊ GESTOR DA INTERNET - CGI ['DEMI GETSCHKO', 'COMITÊ GESTOR DA INTERNET ', ' CGI']
# ASSIS QUINTANS- DEPUTADO ESTADUAL ASSIS QUINTAS, DA PARAÍBA [' DA PARAÍBA']
# ERMÍNIO ALVES DE LIMA NETO, PRESIDENTE DO GRUPO NEW TIME [' PRESIDENTE DO GRUPO NEW TIME']
# JOÃO SOBREIRA DE MOURA NETO, DIRETOR DE DEFESA PROFISSIONAL DA ASSOCIAÇÃO PAULISTA DE MEDICINA [' DIRETOR DE DEFESA PROFISSIONAL DA ASSOCIAÇÃO PAULISTA DE MEDICINA']
# ELEONORA MENICUCCI, MINISTRA DA SECRETARIA DE POLÍTICAS PARA AS MULHERES DA PRESIDÊNCIA DA REPÚBLICA. [' MINISTRA DA SECRETARIA DE POLÍTICAS PARA AS MULHERES DA PRESIDÊNCIA DA REPÚBLICA.']
# ANDRESSA ALVES CARAM, PRESIDENTE MIRIM DE 2013 (PRESIDENTE) [' PRESIDENTE MIRIM DE 2013 (PRESIDENTE)']
# MARIVALDO DE CASTRO PEREIRA, SECRETÁRIO DE ASSUNTOS LEGISLATIVOS DO MINISTÉRIO DA JUSTIÇA. [' SECRETÁRIO DE ASSUNTOS LEGISLATIVOS DO MINISTÉRIO DA JUSTIÇA.']
# PAULO AFONSO CUNHA, DA ASSOCIAÇÃO DOS MILITARES ESTADUAIS DO RIO DE JANEIRO. [' DA ASSOCIAÇÃO DOS MILITARES ESTADUAIS DO RIO DE JANEIRO.']
# LUIZ ERNESTO PUJOL, REPRESENTANTE DO PRESIDENTE DA ASSOCIAÇÃO MÉDICA DO PARANÁ, JOÃO CARLOS BARACHO. [' REPRESENTANTE DO PRESIDENTE DA ASSOCIAÇÃO MÉDICA DO PARANÁ']
# ANTÔNIO JOSÉ ALMEIDA DE MORAES, PRESIDENTE DO SINDICATO DOS POLICIAIS CIVIS DE SERGIPE. [' PRESIDENTE DO SINDICATO DOS POLICIAIS CIVIS DE SERGIPE.']
# MAGNELSON CARLOS DE SOUZA, PRESIDENTE DA FEDERAÇÃO NACIONAL DAS AUTOESCOLAS E CENTROS DE FORMAÇÃO DE CONDUTORES [' PRESIDENTE DA FEDERAÇÃO NACIONAL DAS AUTOESCOLAS E CENTROS DE FORMAÇÃO DE CONDUTORES']
# JONES BORGES LEAL, PRESIDENTE DO SINDICATO DOS POLICIAIS FEDERAIS NO DISTRITO FEDERAL [' PRESIDENTE DO SINDICATO DOS POLICIAIS FEDERAIS NO DISTRITO FEDERAL']
# VANDER MORALES- PRESIDENTE DO SINDICATO DAS EMPRESAS DE PRESTAÇÃO DE SERVIÇOS A TERCEIROS, COLOCAÇÃO E ADMINISTRAÇÃO DE MÃO DE OBRA E DE TRABALHO TEMPORÁRIO DO ESTADO DE SÃO PAULO. [' COLOCAÇÃO E ADMINISTRAÇÃO DE MÃO DE OBRA E DE TRABALHO TEMPORÁRIO DO ESTADO DE SÃO PAULO.']
# ROBERTO BRITO ['ROBERTO BRITO']
# SÉRGIO CARIBÉ, PROCURADOR DO TRIBUNAL DE CONTAS DA UNIÃO. [' PROCURADOR DO TRIBUNAL DE CONTAS DA UNIÃO.']
# PAULO SAFADY SIMÃO, PRESIDENTE DA CÂMARA BRASILEIRA DA INDÚSTRIA DA CONSTRUÇÃO CIVIL. [' PRESIDENTE DA CÂMARA BRASILEIRA DA INDÚSTRIA DA CONSTRUÇÃO CIVIL.']
# PAULO LUIZ SCHMIDT, PRESIDENTE DA ASSOCIAÇ [' PRESIDENTE DA ASSOCIAÇ']
# MAURÍCIO JANUZZI SANTOS, ADVOGADO [' ADVOGADO']
# SERGIO AMADEU, REPRESENTANTE DA UNIVERSIDADE FEDERAL DO ABC; DEMI GETSCHKO, MEMBRO DO COMITÊ GESTOR DA INTERNET NO BRASIL [' REPRESENTANTE DA UNIVERSIDADE FEDERAL DO ABC; DEMI GETSCHKO']
# RICARDO TADEU MARQUES DA FONSECA, DESEMBARGADOR DO TRIBUNAL REGIONAL DO TRABALHO DO PARANÁ. [' DESEMBARGADOR DO TRIBUNAL REGIONAL DO TRABALHO DO PARANÁ.']
# FERNANDO LUIZ ALBUQUERQUE FARIA, PROCURADOR FEDERAL E PROFESSOR DE PROCESSO CIVIL, REPRESENTANTE DO ADVOGADO-GERAL DA UNIÃO [' PROCURADOR FEDERAL E PROFESSOR DE PROCESSO CIVIL']
# LEO BARROS ALMADA (PRESIDENTE DO AMÉRICA FOOTBALL CLUB) ['LEO BARROS ALMADA (PRESIDENTE DO AMÉRICA FOOTBALL CLUB)']
# VALDIRLEI CASTAGNA (SECRETÁRIO-GERAL DA CONFEDERAÇÃO NACIONAL DOS TRABALHADORES NA SAÚDE - CNTS) ['VALDIRLEI CASTAGNA (SECRETÁRIO', 'GERAL DA CONFEDERAÇÃO NACIONAL DOS TRABALHADORES NA SAÚDE ', ' CNTS)']
# FRANCISCO DE SOUSA ANDRADEESPECIALISTA EM CIÊNCIA POLÍTICA) ['FRANCISCO DE SOUSA ANDRADEESPECIALISTA EM CIÊNCIA POLÍTICA)']
# DENISE PIRES PIRES (REPRESENTANTE DA ASSOCIAÇÃO BRASILEIRA DE ENFERMAGEM) ['DENISE PIRES PIRES (REPRESENTANTE DA ASSOCIAÇÃO BRASILEIRA DE ENFERMAGEM)']
# MARUN DAVID CURY (MÉDICO) ['MARUN DAVID CURY (MÉDICO)']
# CLAUDINEI DA ROCHA (VEREADOR DO MUNICÍPIO DE FRANCA, SÃO PAULO) [' SÃO PAULO)']
# ALOÍSIO TIBIRIÇÁ (VICE-PRESIDENTE DO CONSELHO FEDERAL DE MEDICINA - CFM) ['ALOÍSIO TIBIRIÇÁ (VICE', 'PRESIDENTE DO CONSELHO FEDERAL DE MEDICINA ', ' CFM)']
# EDUARDO BANDEIRA DE MELLO (PRESIDENTE DO CLUBE DE REGATAS DO FLAMENGO) ['EDUARDO BANDEIRA DE MELLO (PRESIDENTE DO CLUBE DE REGATAS DO FLAMENGO)']
# ALEXI PORTELA JUNIOR (PRESIDENTE DO CONSELHO FISCAL DO ESPORTE CLUBE VITÓRIA, DA BAHIA) [' DA BAHIA)']
# MAURO ANTÔNIO PIRES DIAS (PRESIDENTE DO CONSELHO REGIONAL DE ENFERMAGEM DE SÃO PAULO) ['MAURO ANTÔNIO PIRES DIAS (PRESIDENTE DO CONSELHO REGIONAL DE ENFERMAGEM DE SÃO PAULO)']
# BRUNO BREITHAUPT (PRESIDENTE DA FEDERAÇÃO DO COMÉRCIO DO ESTADO DE SANTA CATARINA) ['BRUNO BREITHAUPT (PRESIDENTE DA FEDERAÇÃO DO COMÉRCIO DO ESTADO DE SANTA CATARINA)']
# ADEMIR PORTILHO PRONI (SECRETÁRIO DE SAÚDE DO TRABALHADOR DA CONFEDERAÇÃO NACIONAL DOS TRABALHADORES EM SEGURIDADE SOCIAL) ['ADEMIR PORTILHO PRONI (SECRETÁRIO DE SAÚDE DO TRABALHADOR DA CONFEDERAÇÃO NACIONAL DOS TRABALHADORES EM SEGURIDADE SOCIAL)']
# AMARO SALES DE ARAÚJO (PRESIDENTE DA FIERN) ['AMARO SALES DE ARAÚJO (PRESIDENTE DA FIERN)']
# OSVALDO ALBUQUERQUE SOUSA FILHO (PRESIDENTE DO CONSELHO FEDERAL DE ENFERMAGEM) ['OSVALDO ALBUQUERQUE SOUSA FILHO (PRESIDENTE DO CONSELHO FEDERAL DE ENFERMAGEM)']
# DOMINGOS DA SILVA FERREIRA (PRESIDENTE DO SINDICATO DOS PROFISSIONAIS DE ENFERMAGEM DO RIO GRANDE DO NORTE) ['DOMINGOS DA SILVA FERREIRA (PRESIDENTE DO SINDICATO DOS PROFISSIONAIS DE ENFERMAGEM DO RIO GRANDE DO NORTE)']
# PRICILLA MARIA SANTANA - SECRETÁRIA-ADJUNTA DA SECRETARIA DE ACOMPANHAMENTO ECONÔMICO - SEAE, DO MINISTÉRIO DA FAZENDA [' DO MINISTÉRIO DA FAZENDA']
# OLAVO SALES DA SILVEIRA - PRESIDENTE DA ASSOCIAÇÃO BRASILEIRA DE BINGOS - ABRABIN. ['OLAVO SALES DA SILVEIRA ', ' PRESIDENTE DA ASSOCIAÇÃO BRASILEIRA DE BINGOS ', ' ABRABIN.']
# BILU VILLELA- PRESIDENTA DO SINDICATO DAS EMPRESAS DE BINGO DO ESTADO DE SÃO PAULO - SEBESP ['BILU VILLELA', ' PRESIDENTA DO SINDICATO DAS EMPRESAS DE BINGO DO ESTADO DE SÃO PAULO ', ' SEBESP']
# ALESSANDRO SOUZA DE CARVALHO, ----- [' ', '', '', '', '', '']
# ANIZIO SANTOS DE MELO, ----- [' ', '', '', '', '', '']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# RICARDO KEIPER ['RICARDO KEIPER']
# JOANINHA VIEIRA, ----- [' ', '', '', '', '', '']
# HELVIO REBESCHINI (DIRETOR DE PLANEJAMENTO ESTRATÉGICO E MERCADO DA ASSOCIAÇÃO NACIONAL DAS DISTRIBUIDORAS DE COMBUSTÍVEIS, LUBRIFICANTES, LOGÍSTICA E CONVENIÊNCIA - PLURAL) [' LUBRIFICANTES']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# PAULO CÉSAR RIBEIRO LIMA (CONSULTOR LEGISLATIVO DA CÂMARA DOS DEPUTADOS NA ÁREA DE MINAS E ENERGIA) ['PAULO CÉSAR RIBEIRO LIMA (CONSULTOR LEGISLATIVO DA CÂMARA DOS DEPUTADOS NA ÁREA DE MINAS E ENERGIA)']
# PAULO KLIASS (ECONOMISTA E MEMBRO DA CARREIRA DE ESPECIALISTAS EM POLÍTICAS PÚBLICAS E GESTÃO GOVERNAMENTAL DO MINISTÉRIO DO PLANEJAMENTO, ORÇAMENTO E GESTÃO) [' ORÇAMENTO E GESTÃO)']
# JORGE CELESTINO RAMOS (DIRETOR- EXECUTIVO DE REFINO E GÁS NATURAL DA EMPRESA PETRÓLEO BRASILEIRO S/A - PETROBRAS) ['JORGE CELESTINO RAMOS (DIRETOR', ' EXECUTIVO DE REFINO E GÁS NATURAL DA EMPRESA PETRÓLEO BRASILEIRO S/A ', ' PETROBRAS)']
# FERNANDO RODRIGUES DE BAIRROS ['FERNANDO RODRIGUES DE BAIRROS']
# LUIZ DAVIDOVICH (PRESIDENTE DA ACADEMIA BRASILEIRA DE CIÊNCIAS) ['LUIZ DAVIDOVICH (PRESIDENTE DA ACADEMIA BRASILEIRA DE CIÊNCIAS)']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# JOÃO VICENTE DE CARVALHO VIEIRA (DIRETOR DA SECRETARIA DE PETRÓLEO, GÁS NATURAL E BIOCOMBUSTÍVEIS, DO MINISTÉRIO DE MINAS E ENERGIA) [' GÁS NATURAL E BIOCOMBUSTÍVEIS']
# FLÁVIA CALÉ (PRESIDENTE DA ASSOCIAÇÃO NACIONAL DE PÓS-GRADUANDOS - ANPG) ['FLÁVIA CALÉ (PRESIDENTE DA ASSOCIAÇÃO NACIONAL DE PÓS', 'GRADUANDOS ', ' ANPG)']
# BRIAN MIER (SITE BRASIL WIRE) ['BRIAN MIER (SITE BRASIL WIRE)']
# ÁLVARO TOUBES PRATA (SECRETÁRIO DE POLÍTICAS E PROGRAMAS DE PESQUISA E DESENVOLVIMENTO DO MINISTÉRIO DA CIÊNCIA, TECNOLOGIA, INOVAÇÕES E COMUNICAÇÕES) [' TECNOLOGIA']
# JAILTON ALMEIDA (PROFESSOR DE ÉTICA E ESPECIALISTA EM GESTÃO PÚBLICA) ['JAILTON ALMEIDA (PROFESSOR DE ÉTICA E ESPECIALISTA EM GESTÃO PÚBLICA)']
# ROBSON CARNEIRO DOS SANTOS (PRESIDENTE DO SINDICATO DOS REVENDEDORES DE GÁS DE COZINHA DE SÃO PAULO E GRANDE SÃO PAULO) ['ROBSON CARNEIRO DOS SANTOS (PRESIDENTE DO SINDICATO DOS REVENDEDORES DE GÁS DE COZINHA DE SÃO PAULO E GRANDE SÃO PAULO)']
# PAULO KLIASS (ECONOMISTA E MEMBRO DE CARREIRA DE ESPECIALISTA EM POLÍTICAS PÚBLICAS E GESTÃO GOVERNAMENTAL DO MINISTÉRIO DO PLANEJAMENTO, DESENVOLVIMENTO E GESTÃO) [' DESENVOLVIMENTO E GESTÃO)']
# RENATO ROVAI (EDITOR DA REVISTA FÓRUM) ['RENATO ROVAI (EDITOR DA REVISTA FÓRUM)']
# DANIEL FALCÃO (PROFESSOR DA UNIVERSIDADE DE SÃO PAULO - USP E DO INSTITUTO BRASILIENSE DE DIREITO PÚBLICO - IDP) ['DANIEL FALCÃO (PROFESSOR DA UNIVERSIDADE DE SÃO PAULO ', ' USP E DO INSTITUTO BRASILIENSE DE DIREITO PÚBLICO ', ' IDP)']
# LAURA TRESCA (COORDENADORA DO PROGRAMA DE DIREITOS DIGITAIS NA ONG ARTICLE 19) ['LAURA TRESCA (COORDENADORA DO PROGRAMA DE DIREITOS DIGITAIS NA ONG ARTICLE 19)']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# DEYVID BACELAR (COORDENADOR GERAL DO SINDICATO DOS PETROLEIROS DO ESTADO DA BAHIA - SINDIPETRO BAHIA E DIRETOR JURÍDICO DA FEDERAÇÃO ÚNICA DOS PETROLEIROS - FUP) ['DEYVID BACELAR (COORDENADOR GERAL DO SINDICATO DOS PETROLEIROS DO ESTADO DA BAHIA ', ' SINDIPETRO BAHIA E DIRETOR JURÍDICO DA FEDERAÇÃO ÚNICA DOS PETROLEIROS ', ' FUP)']
# MARCOS MENDES (CHEFE DA ASSESSORIA ESPECIAL DO MINISTRO DE ESTADO DA FAZENDA, EDUARDO REFINETTI GUARDIA) [' EDUARDO REFINETTI GUARDIA)']
# PAULO KLIASS (ECONOMISTA MEMBRO DA CARREIRA DE ESPECIALISTA EM POLÍTICAS PÚBLICAS E GESTÃO GOVERNAMENTAL DO MINISTÉRIO DE PLANEJAMENTO, DESENVOLVIMENTO E GESTÃO) [' DESENVOLVIMENTO E GESTÃO)']
# WALISSON MAURÍCIO DE PINHO ARAÚJO, ----- [' ', '', '', '', '', '']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# FREDERICO MEINBERG CEROY (PROMOTOR DE JUSTIÇA DO DISTRITO FEDERAL E PRESIDENTE DO INSTITUTO BRASILEIRO DE DIREITO DIGITAL) ['FREDERICO MEINBERG CEROY (PROMOTOR DE JUSTIÇA DO DISTRITO FEDERAL E PRESIDENTE DO INSTITUTO BRASILEIRO DE DIREITO DIGITAL)']
# JOSÉ CARLOS NASCIMENTO GALIZA (PRESIDENTE DA ASSOCIAÇÃO REMANESCENTE DE QUILOMBOS  FILHOS DE ZUMBI) ['JOSÉ CARLOS NASCIMENTO GALIZA (PRESIDENTE DA ASSOCIAÇÃO REMANESCENTE DE QUILOMBOS  FILHOS DE ZUMBI)']
# LUIZ INÁCIO LULA DA SILVA ['LUIZ INÁCIO LULA DA SILVA']
# MIGUEL SALABERRY FILHO- SECRETÁRIO-GERAL DA SOCIAL DEMOCRACIA SINDICAL ['MIGUEL SALABERRY FILHO', ' SECRETÁRIO', 'GERAL DA SOCIAL DEMOCRACIA SINDICAL']
# MIGUEL DE SOUZA ['MIGUEL DE SOUZA']
# CELSO AMORIM(MINISTRO DAS RELAÇÕES EXTERIORES) ['CELSO AMORIM(MINISTRO DAS RELAÇÕES EXTERIORES)']
# JOSÉ CARLOS ABRAHÃO- PRESIDENTE DA CONFEDERAÇÃO NACIONAL DE SAÚDE, HOSPITAIS, ESTABELECIMENTOS E SERVIÇOS [' HOSPITAIS']
# FRANCISCO DAS CHAGAS DIAS MONTEIRO - CONSELHEIRO SUPLENTE DO CONSELHO NACIONAL DE SAÚDE, REPRESENTANTE DOS TRABALHADORES DE SAÚDE JUNTO AO ÓRGÃO. [' REPRESENTANTE DOS TRABALHADORES DE SAÚDE JUNTO AO ÓRGÃO.']
# MARCOS DE BARROS LISBOA-SECRETÁRIO DE POLÍTICA ECONÔMICA, DO MINISTÉRIO DA FAZENDA [' DO MINISTÉRIO DA FAZENDA']
# JOSÉ LINHARES-- PRESIDENTE DA CONFEDERAÇÃO DAS SANTAS CASAS DE MISERICÓRDIA, HOSPITAIS E ENTIDADES FILANTRÓPICAS, PP-CE [' HOSPITAIS E ENTIDADES FILANTRÓPICAS']
# ROSA LEMOS DE SÁ (SUPERINTENDENTE DE CONSERVAÇÃO DO WWF BRASIL). ['ROSA LEMOS DE SÁ (SUPERINTENDENTE DE CONSERVAÇÃO DO WWF BRASIL).']
# LUIZ  ANSELMO TOURINHO (ENGENHEIRO AGRÔNOMO DA FEDERAÇÃO DA AGRICULTURA DO ESTADO DO PARANÁ). ['LUIZ  ANSELMO TOURINHO (ENGENHEIRO AGRÔNOMO DA FEDERAÇÃO DA AGRICULTURA DO ESTADO DO PARANÁ).']
# MARIA LÚCIA TOJAL - DIRETORA-PRESIDENTE DO HOSPITAL SÃO LUCAS ['MARIA LÚCIA TOJAL ', ' DIRETORA', 'PRESIDENTE DO HOSPITAL SÃO LUCAS']
# FERNANDO ANTONIO ESTEES DE ARAÚJO SILVA (ASSESSOR DA DIRETORIA DE CONTROLE AMBIENTAL DO CENTRO DE RECURSOS AMBIENTAIS). ['FERNANDO ANTONIO ESTEES DE ARAÚJO SILVA (ASSESSOR DA DIRETORIA DE CONTROLE AMBIENTAL DO CENTRO DE RECURSOS AMBIENTAIS).']
# GUSTAVO PEDREIRA DE FREITAS (ENGENHEIRO CIVIL, REPRESENTANTE DA ADEMI — ASSOCIAÇÃO DE DIRIGENTES DE EMPRESAS DO MERCADO IMOBILIÁRIO NO ESTADO DA BAHIA). [' REPRESENTANTE DA ADEMI — ASSOCIAÇÃO DE DIRIGENTES DE EMPRESAS DO MERCADO IMOBILIÁRIO NO ESTADO DA BAHIA).']
# LUCIANO COUTINHO ['LUCIANO COUTINHO']
# MARCÍLIO CARON NETO (PRESIDENTE DA ASSOCIAÇÃO BRASILEIRA DE EMPRESAS FLORESTAIS), ['']
# MARIA NATIVIDADE GOMES TEIXEIRA SANTANA- CONSELHEIRA TITULAR DO CONSELHO NACIONAL DE SAÚDE, REPRESENTANTE DOS TRABALHADORES DE SAÚDE JUNTO AO ÓRGÃO [' REPRESENTANTE DOS TRABALHADORES DE SAÚDE JUNTO AO ÓRGÃO']
# DARC ANTÔNIO DA LUZ COSTA -  VICE-PRESIDENTE DO BANCO NACIONAL DE DESENVOLVIMENTO ECONÔMICO E SOCIAL ['DARC ANTÔNIO DA LUZ COSTA ', '  VICE', 'PRESIDENTE DO BANCO NACIONAL DE DESENVOLVIMENTO ECONÔMICO E SOCIAL']
# DANIEL GOLDBERG- SECRETÁRIO DE DIREITO ECONÔMICO, DO MINISTÉRIO DA JUSTIÇA [' DO MINISTÉRIO DA JUSTIÇA']
# LUIZ FERNANDO VALENTE DE PAIVA- DIRETOR-PRESIDENTE DO ESCRITÓRIO PINHEIRO NETO ADVOGADOS ['LUIZ FERNANDO VALENTE DE PAIVA', ' DIRETOR', 'PRESIDENTE DO ESCRITÓRIO PINHEIRO NETO ADVOGADOS']
# RIBAMAR ALVES ['RIBAMAR ALVES']
# LUIZ INÁCIO LULA DA SILVA (PRESIDENTE DA REPÚBLICA) ['LUIZ INÁCIO LULA DA SILVA (PRESIDENTE DA REPÚBLICA)']
# ALDO REBELO ['ALDO REBELO']
# WALBERTO FERNANDES DE LIMA (PROMOTOR DE JUSTIÇA DO ESTADO DO RIO DE JANEIRO). ['WALBERTO FERNANDES DE LIMA (PROMOTOR DE JUSTIÇA DO ESTADO DO RIO DE JANEIRO).']
# GILSON FREITAS COELHO (SEC EXEC DA ABESPETRO) ['GILSON FREITAS COELHO (SEC EXEC DA ABESPETRO)']
# GIOVANNI ROMANO (SINDICATO DOS TAXISTAS DE SÃO PAULO) ['GIOVANNI ROMANO (SINDICATO DOS TAXISTAS DE SÃO PAULO)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# ILDO LUIS SAUER (PROF DO INST DE ENERG E AMB DA USP) ['ILDO LUIS SAUER (PROF DO INST DE ENERG E AMB DA USP)']
# OLGAMIR AMANCIA FERREIRA (PROFESSORA DA UNIVERSIDADE DE BRASÍLIA) ['OLGAMIR AMANCIA FERREIRA (PROFESSORA DA UNIVERSIDADE DE BRASÍLIA)']
# JOSELICIO FREITAS DOS SANTOS JUNIOR (REPRESENTANTE DO PSOL) ['JOSELICIO FREITAS DOS SANTOS JUNIOR (REPRESENTANTE DO PSOL)']
# MAJOR OLIMPIO ['MAJOR OLIMPIO']
# DANIEL HOMEM DE CARVALHO (VICE-PRESIDENTE DO INSTITUTO JOGO LEGAL E EX-PRESIDENTE DA LOTERJ) ['DANIEL HOMEM DE CARVALHO (VICE', 'PRESIDENTE DO INSTITUTO JOGO LEGAL E EX', 'PRESIDENTE DA LOTERJ)']
# DENILDO RODRIGUES (COORDENADOR NACIONAL DE ARTICULAÇÃO DAS COMUNIDADES NEGRAS RURAIS QUILOMBOLAS) ['DENILDO RODRIGUES (COORDENADOR NACIONAL DE ARTICULAÇÃO DAS COMUNIDADES NEGRAS RURAIS QUILOMBOLAS)']
# GUILHERME ZANINA SCHELB (PROCURADOR REGIONAL DA REPÚBLICA DA 1ª REGIÃO) ['GUILHERME ZANINA SCHELB (PROCURADOR REGIONAL DA REPÚBLICA DA 1ª REGIÃO)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# MAJOR OLIMPIO ['MAJOR OLIMPIO']
# ADILSON AMADEU (VEREADOR DO ESTADO DE SÃO PAULO) ['ADILSON AMADEU (VEREADOR DO ESTADO DE SÃO PAULO)']
# LÚCIA BESSA (SECRETÁRIA ADJUNTA DE POLÍTICAS PARA MULHERES, IGUALDADE RACIAL E DIREITOS HUMANOS DO GOVERNO DO DISTRITO FEDERAL) [' IGUALDADE RACIAL E DIREITOS HUMANOS DO GOVERNO DO DISTRITO FEDERAL)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# MIGUEL REALE JUNIOR (AUTOR DA DENÚNCIA) ['MIGUEL REALE JUNIOR (AUTOR DA DENÚNCIA)']
# MANOEL ARRUDA (CONSELHO DA OAB SECCIONAL DO DISTRITO FEDERAL) ['MANOEL ARRUDA (CONSELHO DA OAB SECCIONAL DO DISTRITO FEDERAL)']
# PATRÍCIA NUNES NAVES (PRESIDENTE DA COMISSÃO ESPECIAL DE PREVENÇÃO AO USO DE DROGAS DA ORDEM DOS ADVOGADOS DO BRASIL DO DISTRITO FEDERAL) ['PATRÍCIA NUNES NAVES (PRESIDENTE DA COMISSÃO ESPECIAL DE PREVENÇÃO AO USO DE DROGAS DA ORDEM DOS ADVOGADOS DO BRASIL DO DISTRITO FEDERAL)']
# VANDERLEI LOURENÇO (PRESIDENTE NACIONAL DO PMDB AFRO) ['VANDERLEI LOURENÇO (PRESIDENTE NACIONAL DO PMDB AFRO)']
# BRUNO BIANCO LEAL (ASSESSOR ESPECIAL DA CASA CIVIL DA PRESIDÊNCIA DA REPÚBLICA) ['BRUNO BIANCO LEAL (ASSESSOR ESPECIAL DA CASA CIVIL DA PRESIDÊNCIA DA REPÚBLICA)']
# FRANCISCO ALBUQUERQUE MOURA (VICE-PRESIDENTE DA CENTRAL DOS SINDICATOS BRASILEIROS - CSB) ['FRANCISCO ALBUQUERQUE MOURA (VICE', 'PRESIDENTE DA CENTRAL DOS SINDICATOS BRASILEIROS ', ' CSB)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# LUÍS CARLOS DE OLIVEIRA (SINDICATO DOS METALÚRGICOS DE SÃO PAULO E MOGI DAS CRUZES) ['LUÍS CARLOS DE OLIVEIRA (SINDICATO DOS METALÚRGICOS DE SÃO PAULO E MOGI DAS CRUZES)']
# JOSÉ DIVANILTON PEREIRA (SECR DE REL INTERNACIONAIS DA CTB) ['JOSÉ DIVANILTON PEREIRA (SECR DE REL INTERNACIONAIS DA CTB)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# CARLOS EDUARDO ABIJAODI (DIR DE DES IND DA CNI) ['CARLOS EDUARDO ABIJAODI (DIR DE DES IND DA CNI)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# DILMA TESSARI (SECRETÁRIA DE SAÚDE DE CAXIAS DO SUL, NO RIO GRANDE DO SUL) [' NO RIO GRANDE DO SUL)']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# JODISMAR AMARO (PRESIDENTE DA FEBRALOT) ['JODISMAR AMARO (PRESIDENTE DA FEBRALOT)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# ANTONIO ALVES DA SILVA (REPRESENTANTE DA FEDERAÇÃO DOS APOSENTADOS DO ESTADO DE SÃO PAULO) ['ANTONIO ALVES DA SILVA (REPRESENTANTE DA FEDERAÇÃO DOS APOSENTADOS DO ESTADO DE SÃO PAULO)']
# MAURO LUCIANO HAUSCHILD (ADVOGADO) ['MAURO LUCIANO HAUSCHILD (ADVOGADO)']
# VALNEIDE NASCIMENTO DOS SANTOS (SECRETÁRIA ESTADUAL DO PSB) ['VALNEIDE NASCIMENTO DOS SANTOS (SECRETÁRIA ESTADUAL DO PSB)']
# IVAN SIMÕES (DIR EXEC DO INST BRASIL DE PETR, GÁS E BIOCOMBUST) [' GÁS E BIOCOMBUST)']
# EDMILSON RODRIGUES ['EDMILSON RODRIGUES']
# JÚLIO MARCELO DE OLIVEIRA (PROCURADOR DO MINISTÉRIO PÚBLICO JUNTO AO TRIBUNAL DE CONTAS DA UNIÃO) ['JÚLIO MARCELO DE OLIVEIRA (PROCURADOR DO MINISTÉRIO PÚBLICO JUNTO AO TRIBUNAL DE CONTAS DA UNIÃO)']
# ROGÉRIO PEREIRA DIAS, ----- [' ', '', '', '', '', '']
# FERNANDA ANTÔNIA DA FONSECA SOBRAL, ----- [' ', '', '', '', '', '']
# MARCELA CARDOSO RODRIGUES, ----- [' ', '', '', '', '', '']
# MINISTRO ABRAHAM WEINTRAUB, ----- [' ', '', '', '', '', '']
# CAROLINA DE MOURA CAMPOS, ----- [' ', '', '', '', '', '']
# SÉRGIO KENJI HOMMA, ----- [' ', '', '', '', '', '']
# ANTÔNIO SÉRGIO TONET, ----- [' ', '', '', '', '', '']
# JOSÉ CLÁUDIO CABRAL MARQUES, ----- [' ', '', '', '', '', '']
# GESSEM BANIWA, ----- [' ', '', '', '', '', '']
# EDUARDO COSTA TAVEIRA, ----- [' ', '', '', '', '', '']
# BELA GIL, ----- [' ', '', '', '', '', '']
# SANDRA CATANHEDE, ----- [' ', '', '', '', '', '']
# LUCIANA MIYOKO MASSUKADO, ----- [' ', '', '', '', '', '']
# MARIA DO SOCORRO LIMA CASTELLO BRANCO, ----- [' ', '', '', '', '', '']
# MINISTRO ABRAHAM WEINTRAUB, ----- [' ', '', '', '', '', '']
# GUSTAVO CHIANCA, ----- [' ', '', '', '', '', '']
# DENIS HELENA RIVAS, ----- [' ', '', '', '', '', '']
# GERMANO LUIZ GOMES VIEIRA, ----- [' ', '', '', '', '', '']
# CLEBER CÉSAR BUZATTO, ----- [' ', '', '', '', '', '']
# REINALDO CENTODUCATTE, ----- [' ', '', '', '', '', '']
# EDVANDIR FELIX DE PAIVA, ----- [' ', '', '', '', '', '']
# FERNANDO MARCELO MENDES, ----- [' ', '', '', '', '', '']
# MARCIO ASTRINI, ----- [' ', '', '', '', '', '']
# JOSÉ SARNEY FILHO, ----- [' ', '', '', '', '', '']
# MINISTRO ABRAHAM WEINTRAUB, ----- [' ', '', '', '', '', '']
# EVARISTO PASCOAL SPENGLER, ----- [' ', '', '', '', '', '']
# BRUNO RENATO TEIXEIRA, ----- [' ', '', '', '', '', '']
# MARIO LUCIO ALVES DE ARAUJO, ----- [' ', '', '', '', '', '']
# JORGE LUIS CAVALCANTI RAMOS, ----- [' ', '', '', '', '', '']
# MINISTRO ABRAHAM WEINTRAUB, ----- [' ', '', '', '', '', '']
# LUIZ ZARREF, ----- [' ', '', '', '', '', '']
# ANDERSON RIBEIRO CORREIA, ----- [' ', '', '', '', '', '']
# THIAGO ALVES DA SILVA, ----- [' ', '', '', '', '', '']
# ALEXANDRE CONCEIÇÃO, ----- [' ', '', '', '', '', '']
# PORAN POTIGUARA, ----- [' ', '', '', '', '', '']
# JOSÉ DO CARMO BARBOSA, ----- [' ', '', '', '', '', '']
# SORAIA APARECIDA CAMPOS NUNES, ----- [' ', '', '', '', '', '']
# NESTOR BONFANTI (1º VICE-PRESIDENTE DA FEDERAÇÃO DOS TRABALHADORES NA AGRICULTURA NO RIO GRANDE DO SUL - FETAG-RS) ['NESTOR BONFANTI (1º VICE', 'PRESIDENTE DA FEDERAÇÃO DOS TRABALHADORES NA AGRICULTURA NO RIO GRANDE DO SUL ', ' FETAG', 'RS)']
# ANTÔNIO CLÁUDIO MARIZ DE OLIVEIRA (REPRESENTANTE DO PRESIDENTE DA REPÚBLICA) ['ANTÔNIO CLÁUDIO MARIZ DE OLIVEIRA (REPRESENTANTE DO PRESIDENTE DA REPÚBLICA)']
# THIAGO TAVARES (REPRESENTANTE DA SAFERNET BRASIL) ['THIAGO TAVARES (REPRESENTANTE DA SAFERNET BRASIL)']
# LARISSA FERREIRA (REPRESENTANTE DA JUVENTUDE DO PTB) ['LARISSA FERREIRA (REPRESENTANTE DA JUVENTUDE DO PTB)']
# GIULIANNO CARTAXO (APRESENTADOR DOS PROGRAMAS DF NO AR E BALANÇO GERAL, DA TV RECORD) [' DA TV RECORD)']
# PEDRO CELESTINO DA SILVA PEREIRA FILHO (PRESIDENTE DO CLUBE DE ENGENHARIA) ['PEDRO CELESTINO DA SILVA PEREIRA FILHO (PRESIDENTE DO CLUBE DE ENGENHARIA)']
# TIAGO LACERDA DE BRITO (PRESIDENTE DO PSC JOVEM DO DISTRITO FEDERAL) ['TIAGO LACERDA DE BRITO (PRESIDENTE DO PSC JOVEM DO DISTRITO FEDERAL)']
# MARIA DAS NEVES (UNIÃO BRASILEIRA DE MULHERES) ['MARIA DAS NEVES (UNIÃO BRASILEIRA DE MULHERES)']
# JOÃO PAULO (COMISSÃO DE DIREITO TRIBUTÁRIO DA ORDEM DOS ADVOGADOS DO BRASIL - OAB DE MINAS GERAIS E PROFESSOR DE DIREITO TRIBUTÁRIO DA PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS - PUC MINAS) ['JOÃO PAULO (COMISSÃO DE DIREITO TRIBUTÁRIO DA ORDEM DOS ADVOGADOS DO BRASIL ', ' OAB DE MINAS GERAIS E PROFESSOR DE DIREITO TRIBUTÁRIO DA PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS ', ' PUC MINAS)']
# MAURÍCIO ANTÔNIO LOPES (PRESIDENTE DA EMBRAPA) ['MAURÍCIO ANTÔNIO LOPES (PRESIDENTE DA EMBRAPA)']
# RONALD CINTRA SHELLARD (DIRETOR DO CENTRO BRASILEIRO DE PESQUISAS FÍSICAS - CBPF, DO MINISTÉRIO DA CIÊNCIA, TECNOLOGIA, INOVAÇÕES E COMUNICAÇÕES) [' DO MINISTÉRIO DA CIÊNCIA']
# GILMAR PEREIRA DE OLIVEIRA (DIRETOR DE REGIONAIS DO SINDICATO DOS AGENTES DE SEGURANÇA PENITENCIÁRIA DO ESTADO DE SÃO PAULO) ['GILMAR PEREIRA DE OLIVEIRA (DIRETOR DE REGIONAIS DO SINDICATO DOS AGENTES DE SEGURANÇA PENITENCIÁRIA DO ESTADO DE SÃO PAULO)']
# MÁRCIA ABRAHÃO MOURA (REITORA DA UNIVERSIDADE DE BRASÍLIA) ['MÁRCIA ABRAHÃO MOURA (REITORA DA UNIVERSIDADE DE BRASÍLIA)']
# LUIZ MELLO (VICE-PRESIDENTE DA ASSOCIAÇÃO NACIONAL DE PESQUISA E DESENVOLVIMENTO DAS EMPRESAS INOVADORAS - ANPEI) ['LUIZ MELLO (VICE', 'PRESIDENTE DA ASSOCIAÇÃO NACIONAL DE PESQUISA E DESENVOLVIMENTO DAS EMPRESAS INOVADORAS ', ' ANPEI)']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# SÉRGIO DIAS HENRIQUES (DIRETOR ADMINISTRATIVO DA FUNDAÇÃO CRISTIANO VARELLA) ['SÉRGIO DIAS HENRIQUES (DIRETOR ADMINISTRATIVO DA FUNDAÇÃO CRISTIANO VARELLA)']
# MÁRCIO ASTRINI (COORDENADOR DE POLÍTICAS PÚBLICAS DO GREENPEACE DO BRASIL) ['MÁRCIO ASTRINI (COORDENADOR DE POLÍTICAS PÚBLICAS DO GREENPEACE DO BRASIL)']
# JOSÉ RIVALDO DA SILVA (PRESIDENTE DA FEDERAÇÃO NACIONAL DOS TRABALHADORES DOS CORREIOS) ['JOSÉ RIVALDO DA SILVA (PRESIDENTE DA FEDERAÇÃO NACIONAL DOS TRABALHADORES DOS CORREIOS)']
# JOÃO PAULO KLEINÜBING ['JOÃO PAULO KLEINÜBING']
# FABRÍCIO ALEXANDRE LUIZ LIMA (DIRETOR JURÍDICO DA ASSOCIAÇÃO DOS PRAÇAS E POLICIAIS E BOMBEIROS MILITARES DO ESTADO DE MINAS GERAIS) ['FABRÍCIO ALEXANDRE LUIZ LIMA (DIRETOR JURÍDICO DA ASSOCIAÇÃO DOS PRAÇAS E POLICIAIS E BOMBEIROS MILITARES DO ESTADO DE MINAS GERAIS)']
# LU MAI (VICE-PRESIDENTE E SECRETÁRIO-GERAL DA FUNDAÇÃO DE DESENVOLVIMENTO DE PESQUISAS DA CHINA) ['LU MAI (VICE', 'PRESIDENTE E SECRETÁRIO', 'GERAL DA FUNDAÇÃO DE DESENVOLVIMENTO DE PESQUISAS DA CHINA)']
# RENATA MIELLI (COORDENADORA-GERAL DO FÓRUM NACIONAL PELA DEMOCRATIZAÇÃO DA COMUNICAÇÃO E SECRETÁRIA-GERAL DO CENTRO DE ESTUDOS DA MÍDIA ALTERNATIVA BARÃO DE ITARARÉ) ['RENATA MIELLI (COORDENADORA', 'GERAL DO FÓRUM NACIONAL PELA DEMOCRATIZAÇÃO DA COMUNICAÇÃO E SECRETÁRIA', 'GERAL DO CENTRO DE ESTUDOS DA MÍDIA ALTERNATIVA BARÃO DE ITARARÉ)']
# EDILEUSA PAIVA (REPRESENTANTE DO GRUPO ESPOSAS UNIDAS PMDF) ['EDILEUSA PAIVA (REPRESENTANTE DO GRUPO ESPOSAS UNIDAS PMDF)']
# DÉBORA DUPRAT (PROCURADORA FEDERAL DOS DIREITOS DOS CIDADÃOS) ['DÉBORA DUPRAT (PROCURADORA FEDERAL DOS DIREITOS DOS CIDADÃOS)']
# EDEMUNDO DIAS DE OLIVEIRA FILHO (DELEGADO DE POLÍCIA CIVIL DE GOIÁS) ['EDEMUNDO DIAS DE OLIVEIRA FILHO (DELEGADO DE POLÍCIA CIVIL DE GOIÁS)']
# ROBERTO ÁTILA AMARAL VIEIRA (EX-MINISTRO DA CIÊNCIA, TECNOLOGIA, INOVAÇÕES E COMUNICAÇÕES) [' TECNOLOGIA']
# MARCELO GODOY (PROCURADOR DA REPÚBLICA E SECRETÁRIO-EXECUTIVO DA 7ª CÂMARA DE COORDENAÇÃO E REVISÃO - CONTROLE EXTERNO DA ATIVIDADE POLICIAL E SISTEMA PRISIONAL) ['MARCELO GODOY (PROCURADOR DA REPÚBLICA E SECRETÁRIO', 'EXECUTIVO DA 7ª CÂMARA DE COORDENAÇÃO E REVISÃO ', ' CONTROLE EXTERNO DA ATIVIDADE POLICIAL E SISTEMA PRISIONAL)']
# MÁRCIO MENDONÇA FRANÇA- PRESIDENTE DO SINDICADO DAS INDÚSTRIAS DO VESTUÁRIO DO DISTRITO FEDERAL - SINDIVESTE ['MÁRCIO MENDONÇA FRANÇA', ' PRESIDENTE DO SINDICADO DAS INDÚSTRIAS DO VESTUÁRIO DO DISTRITO FEDERAL ', ' SINDIVESTE']
# CLAUDE FIRMEZ - VICE-PRESIDENTA DA FUNDAÇÃO OSWALDO CRUZ. ['CLAUDE FIRMEZ ', ' VICE', 'PRESIDENTA DA FUNDAÇÃO OSWALDO CRUZ.']
# ROBERTO SANTIAGO - VICE-PRESIDENTE DA UNIÃO GERAL DOS TRABALHADORES - UGT ['ROBERTO SANTIAGO ', ' VICE', 'PRESIDENTE DA UNIÃO GERAL DOS TRABALHADORES ', ' UGT']
# RODRIGO FURTADO DA SILVA ['RODRIGO FURTADO DA SILVA']
# ROQUE PELLIZZARO JÚNIOR- PRESIDENTE DA CONFEDERAÇÃO NACIONAL DE DIRIGENTES LOJISTAS - CNDL ['ROQUE PELLIZZARO JÚNIOR', ' PRESIDENTE DA CONFEDERAÇÃO NACIONAL DE DIRIGENTES LOJISTAS ', ' CNDL']
# KAREN REGINA SUASSUNA - REPRESENTANTE DA ORGANIZAÇÃO NÃO GOVERNAMENTAL FUNDO MUNDIAL PARA A NATUREZA (WORLD WIDE FUND FOR NATURE - WWF) NO BRASIL ['KAREN REGINA SUASSUNA ', ' REPRESENTANTE DA ORGANIZAÇÃO NÃO GOVERNAMENTAL FUNDO MUNDIAL PARA A NATUREZA (WORLD WIDE FUND FOR NATURE ', ' WWF) NO BRASIL']
# FLÁVIO BORGES BOTELHO FILHO- PRESIDENTE DA ASSOCIAÇÃO DOS DOCENTES DA UNIVERSIDADE DE BRASÍLIA - ADUNB ['FLÁVIO BORGES BOTELHO FILHO', ' PRESIDENTE DA ASSOCIAÇÃO DOS DOCENTES DA UNIVERSIDADE DE BRASÍLIA ', ' ADUNB']
# MACO MAIA (PRESIDENTE) ['MACO MAIA (PRESIDENTE)']
# CLEMENTE GANZ LÚCIO - DIRETOR-TÉCNICO DO DEPARTAMENTO INTERSINDICAL DE ESTATÍSTICA E ESTUDOS SOCIOECONÔMICOS - DIEESE. ['CLEMENTE GANZ LÚCIO ', ' DIRETOR', 'TÉCNICO DO DEPARTAMENTO INTERSINDICAL DE ESTATÍSTICA E ESTUDOS SOCIOECONÔMICOS ', ' DIEESE.']
# GERALDO TADEU MOREIRA MONTEIRO- DIRETOR-PRESIDENTE DO INSTITUTO BRASILEIRO DE PESQUISA SOCIAL — IBPS ['GERALDO TADEU MOREIRA MONTEIRO', ' DIRETOR', 'PRESIDENTE DO INSTITUTO BRASILEIRO DE PESQUISA SOCIAL — IBPS']
# AGUINALDO DINIZ FILHO- PRESIDENTE DA ASSOCIAÇÃO BRASILEIRA DA INDÚSTRIA TÊXTIL E DE CONFECÇÃO - ABIT ['AGUINALDO DINIZ FILHO', ' PRESIDENTE DA ASSOCIAÇÃO BRASILEIRA DA INDÚSTRIA TÊXTIL E DE CONFECÇÃO ', ' ABIT']
# RENATO CASAGRANDE - PRESIDENTE DA COMISSÃO DE MEIO AMBIENTE, DEFESA DO CONSUMIDOR E FISCALIZAÇÃO E CONTROLE, DO SENADO FEDERAL. [' DEFESA DO CONSUMIDOR E FISCALIZAÇÃO E CONTROLE']
# LUIZ MOREIRA GOMES JÚNIOR - PROFESSOR DA ESCOLA SUPERIOR DOM HELDER CÂMARA, EM BELO HORIZONTE, ESTADO DE MINAS GERAIS [' EM BELO HORIZONTE']
# ANTÔNIO NETO- PRESIDENTE DA CENTRAL GERAL DOS TRABALHADORES DO BRASIL - CGTB ['ANTÔNIO NETO', ' PRESIDENTE DA CENTRAL GERAL DOS TRABALHADORES DO BRASIL ', ' CGTB']
# JOÃO ANTÔNIO DE MORAES- COORDENADOR-GERAL DA FEDERAÇÃO ÚNICA DOS PETROLEIROS - FUP. ['JOÃO ANTÔNIO DE MORAES', ' COORDENADOR', 'GERAL DA FEDERAÇÃO ÚNICA DOS PETROLEIROS ', ' FUP.']
# ARMANDO MONTEIRO- PRESIDENTE DA CONFEDERAÇÃO NACIONAL DA INDÚSTRIA - CNI ['ARMANDO MONTEIRO', ' PRESIDENTE DA CONFEDERAÇÃO NACIONAL DA INDÚSTRIA ', ' CNI']
# MÔNICA NUNES - REPRESENTANTE DA REVISTA PLANETA SUSTENTÁVEL, PUBLICADA PELA EDITORA ABRIL [' PUBLICADA PELA EDITORA ABRIL']
# EDUARDO TEIXEIRA ALVES - DIRETOR DA CENTRAL ÚNICA DOS TRABALHADORES - CUT NO MUNICÍPIO DE GUARULHOS, ESTADO DE SÃO PAULO [' ESTADO DE SÃO PAULO']
# LUCIANO ATHAYDE CHAVES- PRESIDENTE DA ASSOCIAÇÃO NACIONAL DOS MAGISTRADOS DA JUSTIÇA DO TRABALHO - ANAMATRA ['LUCIANO ATHAYDE CHAVES', ' PRESIDENTE DA ASSOCIAÇÃO NACIONAL DOS MAGISTRADOS DA JUSTIÇA DO TRABALHO ', ' ANAMATRA']
# FRANCISCO DAS CHAGAS SILVA - SUPERINTENDENTE DE DEFESA CIVIL DE IMPERATRIZ, ESTADO DO MARANHÃO [' ESTADO DO MARANHÃO']
# FLÁVIO CASTELO BRANCO- GERENTE-EXECUTIVO DE POLÍTICA ECONÔMICA DA CONFEDERAÇÃO NACIONAL DA INDÚSTRIA - CNI ['FLÁVIO CASTELO BRANCO', ' GERENTE', 'EXECUTIVO DE POLÍTICA ECONÔMICA DA CONFEDERAÇÃO NACIONAL DA INDÚSTRIA ', ' CNI']
# MARCO ANTÔNIO ROSSI- PRESIDENTE DA FEDERAÇÃO NACIONAL DE PREVIDÊNCIA PRIVADA E VIDA - FENAPREVI. S.SA. ['MARCO ANTÔNIO ROSSI', ' PRESIDENTE DA FEDERAÇÃO NACIONAL DE PREVIDÊNCIA PRIVADA E VIDA ', ' FENAPREVI. S.SA.']
# ANTONIO VASCONCELOS (PRESIDENTE DA RESERVA EXTRATIVISTA ITUXI, NO MUNICÍPIO DE LÁBREA, AMAZONAS) [' NO MUNICÍPIO DE LÁBREA']
# RICARDO LEWANDOWSKI - PRESIDENTE DO TRIBUNAL SUPERIOR ELEITORAL, ['']
# LUÍS ALBERTO ['LUÍS ALBERTO']
# ALOIZIO MERCADANTE ( MINISTRO DE ESTADO  DA CIÊNCIA, TECNOLOGIA E INOVAÇÃO). [' TECNOLOGIA E INOVAÇÃO).']
# MARIA DO ROSÁRIO (MINISTRA CHEFE DA SECRETARIA DE DIREITOS HUMANOS DA PRESIDÊNCIA DA REPÚBLICA) ['MARIA DO ROSÁRIO (MINISTRA CHEFE DA SECRETARIA DE DIREITOS HUMANOS DA PRESIDÊNCIA DA REPÚBLICA)']
# WAGNER GOMES- PRESIDENTE DA CENTRAL DOS TRABALHADORES E TRABALHADORAS DO BRASIL - CTB ['WAGNER GOMES', ' PRESIDENTE DA CENTRAL DOS TRABALHADORES E TRABALHADORAS DO BRASIL ', ' CTB']
# CEZAR PELUSO- PRESIDENTE DO SUPREMO TRIBUNAL FEDERAL, ['']
# FRANCISCO TADEU VAZ E SILVA (ASSENTAMENTO EXTRATIVISTA PRAIA ALTA PIRANHEIRA) ['FRANCISCO TADEU VAZ E SILVA (ASSENTAMENTO EXTRATIVISTA PRAIA ALTA PIRANHEIRA)']
# WALDEMAR CARNEIRO LEÃO ['WALDEMAR CARNEIRO LEÃO']
# ALOIZIO MERCADANTE ( MINISTRO DE ESTADO  DA CIÊNCIA, TECNOLOGIA E INOVAÇÃO). [' TECNOLOGIA E INOVAÇÃO).']
# CLAUDELICE SILVA DOS SANTOS (CONSELHO NACIONAL DE POPULAÇÕES EXTRATIVISTAS) ['CLAUDELICE SILVA DOS SANTOS (CONSELHO NACIONAL DE POPULAÇÕES EXTRATIVISTAS)']
# ÁLVARO SOLÓN DE FRANÇA- PRESIDENTE DA ASSOCIAÇÃO NACIONAL DOS AUDITORES FISCAIS DA RECEITA FEDERAL DO BRASIL - ANFIP. ['ÁLVARO SOLÓN DE FRANÇA', ' PRESIDENTE DA ASSOCIAÇÃO NACIONAL DOS AUDITORES FISCAIS DA RECEITA FEDERAL DO BRASIL ', ' ANFIP.']
# MÁRCIA ÁLAMO - ADVOGADA DO CENTRO DE ASSISTÊNCIA AO DESENVOLVIMENTO DA MULHER - ORGANIZAÇÃO NÃO GOVERNAMENTAL MARIA BONITA ['MÁRCIA ÁLAMO ', ' ADVOGADA DO CENTRO DE ASSISTÊNCIA AO DESENVOLVIMENTO DA MULHER ', ' ORGANIZAÇÃO NÃO GOVERNAMENTAL MARIA BONITA']
# MAGNUS RIBAS APOSTÓLICO-SUPERINTENDENTE DE RELAÇÕES DE TRABALHO DA FEDERAÇÃO NACIONAL DOS BANCOS - FENABAN E DA FEDERAÇÃO BRASILEIRA DE BANCOS - FEBRABAN ['MAGNUS RIBAS APOSTÓLICO', 'SUPERINTENDENTE DE RELAÇÕES DE TRABALHO DA FEDERAÇÃO NACIONAL DOS BANCOS ', ' FENABAN E DA FEDERAÇÃO BRASILEIRA DE BANCOS ', ' FEBRABAN']
# MARIA CONCEIÇÃO ROCHA PINHEIRO - EMPRESÁRIA, ADVOGADA E ASSISTENTE SOCIAL. [' ADVOGADA E ASSISTENTE SOCIAL.']
# MARLENE LIBARDONI - DIRETORA-EXECUTIVA DA AGENDE — AÇÕES EM GÊNERO, CIDADANIA E DESENVOLVIMENTO. [' CIDADANIA E DESENVOLVIMENTO.']
# MARCOS JOAQUIM GONÇALVES ALVES-MEMBRO DO CONSELHO DE RELAÇÕES TRABALHISTAS DA ASSOCIAÇÃO BRASILEIRA DA INFRA-ESTRUTURA E INDÚSTRIAS DE BASE - ABDIB ['MARCOS JOAQUIM GONÇALVES ALVES', 'MEMBRO DO CONSELHO DE RELAÇÕES TRABALHISTAS DA ASSOCIAÇÃO BRASILEIRA DA INFRA', 'ESTRUTURA E INDÚSTRIAS DE BASE ', ' ABDIB']
# MARISA SANABRIA - PSICÓLOGA, MESTRE EM FILOSOFIA PELA UNIVERSIDADE FEDERAL DE MINAS GERAIS — UFMG E MEMBRO DA ACADEMIA FEMININA MINEIRA DE LETRAS [' MESTRE EM FILOSOFIA PELA UNIVERSIDADE FEDERAL DE MINAS GERAIS — UFMG E MEMBRO DA ACADEMIA FEMININA MINEIRA DE LETRAS']
# KÁTIA MARIA BARRETO SOUTO - MEMBRO DA COORDENAÇÃO NACIONAL E CONSELHO CONSULTIVO DA UNIÃO BRASILEIRA DE MULHERES - UBM ['KÁTIA MARIA BARRETO SOUTO ', ' MEMBRO DA COORDENAÇÃO NACIONAL E CONSELHO CONSULTIVO DA UNIÃO BRASILEIRA DE MULHERES ', ' UBM']
# NEUSA RISETTE - DIRETORA-EXECUTIVA DA ASSOCIAÇÃO NEO TV. ['NEUSA RISETTE ', ' DIRETORA', 'EXECUTIVA DA ASSOCIAÇÃO NEO TV.']
# LUIS CUZA - PRESIDENTE DA TELCOMP, ASSOCIAÇÃO BRASILEIRA DAS PRESTADORAS DE SERVIÇOS DE TELECOMUNICAÇÕES COMPETITIVAS. [' ASSOCIAÇÃO BRASILEIRA DAS PRESTADORAS DE SERVIÇOS DE TELECOMUNICAÇÕES COMPETITIVAS.']
# WENDI DAIANE TAVARES DOS SANTOS (DEPUTADA MIRIM) ['WENDI DAIANE TAVARES DOS SANTOS (DEPUTADA MIRIM)']
# SARAH DE ROURE - SECRETÁRIA-EXECUTIVA DA MARCHA MUNDIAL DE MULHERES ['SARAH DE ROURE ', ' SECRETÁRIA', 'EXECUTIVA DA MARCHA MUNDIAL DE MULHERES']
# PAULO PEREIRA DA SILVA ['PAULO PEREIRA DA SILVA']
# MATHEUS FERREIRA DE SOUZA (DEPUTADO MIRIM) ['MATHEUS FERREIRA DE SOUZA (DEPUTADO MIRIM)']
# MARCELO CORDEIRO - VICE-PRESIDENTE DA ABRATEL — ASSOCIAÇÃO BRASILEIRA DE RADIODIFUSÃO, TECNOLOGIA E TELECOMUNICAÇÕES. [' TECNOLOGIA E TELECOMUNICAÇÕES.']
# MARCO ANTONIO REIS GUARITA-DIRETOR DE RELAÇÕES INSTITUCIONAIS DA CONFEDERAÇÃO NACIONAL DA INDÚSTRIA - CNI ['MARCO ANTONIO REIS GUARITA', 'DIRETOR DE RELAÇÕES INSTITUCIONAIS DA CONFEDERAÇÃO NACIONAL DA INDÚSTRIA ', ' CNI']
# ANA BEATRIZ ARAÚJO (DEPUTADA MIRIM) ['ANA BEATRIZ ARAÚJO (DEPUTADA MIRIM)']
# PAULO RODRIGUES MENDES - PRESIDENTE DA ASSOCIAÇÃO NACIONAL DOS ESPECIALISTAS EM REGULAÇÃO - ANER ['PAULO RODRIGUES MENDES ', ' PRESIDENTE DA ASSOCIAÇÃO NACIONAL DOS ESPECIALISTAS EM REGULAÇÃO ', ' ANER']
# RAFAELA ROCHA OLIVEIRA (DEPUTADA MIRIM) ['RAFAELA ROCHA OLIVEIRA (DEPUTADA MIRIM)']
# JOSÉ LUCAS FERREIRA (DEPUTADO MIRIM) ['JOSÉ LUCAS FERREIRA (DEPUTADO MIRIM)']
# STEFANE DA SILVA BARBOSA ( DEPUTADA MIRIM) ['STEFANE DA SILVA BARBOSA ( DEPUTADA MIRIM)']
# JOSÉ ANTÔNIO MORONI - DIRETOR DE RELAÇÕES INSTITUCIONAIS DA ASSOCIAÇÃO BRASILEIRA DE ORGANIZAÇÕES NÃO-GOVERNAMENTAIS - ABONG ['JOSÉ ANTÔNIO MORONI ', ' DIRETOR DE RELAÇÕES INSTITUCIONAIS DA ASSOCIAÇÃO BRASILEIRA DE ORGANIZAÇÕES NÃO', 'GOVERNAMENTAIS ', ' ABONG']
# FERNANDO XAVIER FERREIRA - PRESIDENTE DO CONSELHO SUPERIOR DE INFRA-ESTRUTURA DA FEDERAÇÃO DAS INDÚSTRIAS DO ESTADO DE SÃO PAULO - FIESP ['FERNANDO XAVIER FERREIRA ', ' PRESIDENTE DO CONSELHO SUPERIOR DE INFRA', 'ESTRUTURA DA FEDERAÇÃO DAS INDÚSTRIAS DO ESTADO DE SÃO PAULO ', ' FIESP']
# IZABEL MAIOR - COORDENADORA-GERAL DA COORDENADORIA NACIONAL PARA INTEGRAÇÃO DA PESSOA PORTADORA DE DEFICIÊNCIA DO MINISTÉRIO DA JUSTIÇA. ['IZABEL MAIOR ', ' COORDENADORA', 'GERAL DA COORDENADORIA NACIONAL PARA INTEGRAÇÃO DA PESSOA PORTADORA DE DEFICIÊNCIA DO MINISTÉRIO DA JUSTIÇA.']
# ARLINDO CHINAGLIA (PRESIDENTE DA CÂMARA DOS DEPUTADOS) ['ARLINDO CHINAGLIA (PRESIDENTE DA CÂMARA DOS DEPUTADOS)']
# DELEY (PRESIDENTE) ['DELEY (PRESIDENTE)']
# LUIZ CLÁUDIO PONTES- SUPERINTENDENTE DE POLÍTICAS PARA PESSOAS COM DEFICIÊNCIA DO GOVERNO DO ESTADO DO RIO DE JANEIRO - IBDD. ['LUIZ CLÁUDIO PONTES', ' SUPERINTENDENTE DE POLÍTICAS PARA PESSOAS COM DEFICIÊNCIA DO GOVERNO DO ESTADO DO RIO DE JANEIRO ', ' IBDD.']
# JOSÉF ANDERE LIMA MERIS DE CARVALHO (PRESIDENTE MIRIM) ['JOSÉF ANDERE LIMA MERIS DE CARVALHO (PRESIDENTE MIRIM)']
# TALITA SERRA FERREIRA BATISTA (PRESIDENTE MIRIM) ['TALITA SERRA FERREIRA BATISTA (PRESIDENTE MIRIM)']
# SUEIDE MIRANDA LEITE- DIRETOR-PRESIDENTE DO INSTITUTO CULTURAL E PROFISSIONALIZANTE DE PESSOAS PORTADORAS DE DEFICIÊNCIA DO DISTRITO FEDERAL. ['SUEIDE MIRANDA LEITE', ' DIRETOR', 'PRESIDENTE DO INSTITUTO CULTURAL E PROFISSIONALIZANTE DE PESSOAS PORTADORAS DE DEFICIÊNCIA DO DISTRITO FEDERAL.']
# JOÃO PAULO DUTRA DE ANDRADE - CONSELHEIRO DA AGÊNCIA REGULADORA DE ENERGIA E SANEAMENTO BÁSICO DO ESTADO DO RIO DE JANEIRO - AGENERSA E DIRETOR DA ASSOCIAÇÃO BRASILEIRA DE AGÊNCIAS DE REGULAÇÃO - ABAR ['JOÃO PAULO DUTRA DE ANDRADE ', ' CONSELHEIRO DA AGÊNCIA REGULADORA DE ENERGIA E SANEAMENTO BÁSICO DO ESTADO DO RIO DE JANEIRO ', ' AGENERSA E DIRETOR DA ASSOCIAÇÃO BRASILEIRA DE AGÊNCIAS DE REGULAÇÃO ', ' ABAR']
# JOÃO MARIA MEDEIROS DE OLIVEIRA - PRESIDENTE DO SINDICATO NACIONAL DOS SERVIDORES DAS AGÊNCIAS NACIONAIS DE REGULAÇÃO - SINAGÊNCIAS ['JOÃO MARIA MEDEIROS DE OLIVEIRA ', ' PRESIDENTE DO SINDICATO NACIONAL DOS SERVIDORES DAS AGÊNCIAS NACIONAIS DE REGULAÇÃO ', ' SINAGÊNCIAS']
# LARISSA NICOLAU FERNANDES GONÇALVES (DEPUTADA MIRIM) ['LARISSA NICOLAU FERNANDES GONÇALVES (DEPUTADA MIRIM)']
# ANA LIÉSI THURLER - FILÓSOFA, SOCIÓLOGA E MEMBRO DO FÓRUM DE MULHERES DO DISTRITO FEDERAL. [' SOCIÓLOGA E MEMBRO DO FÓRUM DE MULHERES DO DISTRITO FEDERAL.']
# THUANY MOURÃO MOURA (DEPUTADA MIRIM) ['THUANY MOURÃO MOURA (DEPUTADA MIRIM)']
# ANTÔNIO MODESTO DA SILVEIRA - EX-DEPUTADO FEDERAL E ADVOGADO. ['ANTÔNIO MODESTO DA SILVEIRA ', ' EX', 'DEPUTADO FEDERAL E ADVOGADO.']
# ROSA CIMIANA DOS SANTOS - FILHA DE EX-PRESO POLÍTICO E REPRESENTANTE DAS VIÚVAS E HERDEIROS ['ROSA CIMIANA DOS SANTOS ', ' FILHA DE EX', 'PRESO POLÍTICO E REPRESENTANTE DAS VIÚVAS E HERDEIROS']
# WILLIAM FRANÇA (DIRETOR DA SECRETARIA DE COMUNICAÇÃO SOCIAL DA CÂMARA DOS DEPUTADOS) ['WILLIAM FRANÇA (DIRETOR DA SECRETARIA DE COMUNICAÇÃO SOCIAL DA CÂMARA DOS DEPUTADOS)']
# ALEXANDER GRACO MOREIRA TEIXEIRA (PRESIDENTE MIRIM) (PRESIDENTE) ['ALEXANDER GRACO MOREIRA TEIXEIRA (PRESIDENTE MIRIM) (PRESIDENTE)']
# MARIANA SCHMIDT VIEIRA (DEPUTADA MIRIM) ['MARIANA SCHMIDT VIEIRA (DEPUTADA MIRIM)']
# ALEXANDER GRACO MOREIRA TEIXEIRA (PRESIDENTE MIRIM) ['ALEXANDER GRACO MOREIRA TEIXEIRA (PRESIDENTE MIRIM)']
# MARIA REGINA GONÇALVES - PRESIDENTA DO PARTIDO VERDE MULHER DE DIADEMA, SÃO PAULO. [' SÃO PAULO.']
# JOÃO ANTÔNIO ZUFFO - COORDENADOR-GERAL DO LABORATÓRIO DE SISTEMAS INTEGRÁVEIS DO DEPARTAMENTO DE ENGENHARIA DE SISTEMAS ELETRÔNICOS DA ESCOLA POLITÉCNICA DA UNIVERSIDADE DE SÃO PAULO - USP ['JOÃO ANTÔNIO ZUFFO ', ' COORDENADOR', 'GERAL DO LABORATÓRIO DE SISTEMAS INTEGRÁVEIS DO DEPARTAMENTO DE ENGENHARIA DE SISTEMAS ELETRÔNICOS DA ESCOLA POLITÉCNICA DA UNIVERSIDADE DE SÃO PAULO ', ' USP']
# MÁRIO BAUMGARTEN- REPRESENTANTE DA COALIZÃO DVB BRASIL - SISTEMA BRASILEIRO, PADRÃO MUNDIAL [' PADRÃO MUNDIAL']
# TALITHA SERRA FERREIRA BATISTA (DEPUTADA MIRIM ['TALITHA SERRA FERREIRA BATISTA (DEPUTADA MIRIM']
# ADONIAS COSTA SILVEIRA - PRESIDENTE DA FUNDAÇÃO INSTITUTO NACIONAL DE TELECOMUNICAÇÕES - FINATEL. ['ADONIAS COSTA SILVEIRA ', ' PRESIDENTE DA FUNDAÇÃO INSTITUTO NACIONAL DE TELECOMUNICAÇÕES ', ' FINATEL.']
# ALEXANDER GRACO MOREIRA TEIXEIRA (PRESIDENTE MIRIM) ['ALEXANDER GRACO MOREIRA TEIXEIRA (PRESIDENTE MIRIM)']
# GUSTAVO GINDRE- CONSELHEIRO DO COLETIVO INTERVOZES E COORDENADOR-GERAL DO INSTITUTO DE ESTUDOS E PROJETOS EM COMUNICAÇÃO E CULTURA. S.SA. ['GUSTAVO GINDRE', ' CONSELHEIRO DO COLETIVO INTERVOZES E COORDENADOR', 'GERAL DO INSTITUTO DE ESTUDOS E PROJETOS EM COMUNICAÇÃO E CULTURA. S.SA.']
# ANTONIO CARVALHO E SILVA NETO (REPRESENTANTE DOS JOVENS SERVIDORES DA CÂMARA DOS DEPUTADOS) ['ANTONIO CARVALHO E SILVA NETO (REPRESENTANTE DOS JOVENS SERVIDORES DA CÂMARA DOS DEPUTADOS)']
# ELEONORA MENICUCCI DE OLIVEIRA (MINISTRA DA SECRETARIA DE POLÍTICAS PÚBLICAS PARA AS MULHERES) ['ELEONORA MENICUCCI DE OLIVEIRA (MINISTRA DA SECRETARIA DE POLÍTICAS PÚBLICAS PARA AS MULHERES)']
# IDELI SALVATTI- MINISTRA-CHEFE DA SECRETARIA DE DIREITOS HUMANOS DA PRESIDÊNCIA DA REPÚBLICA ['IDELI SALVATTI', ' MINISTRA', 'CHEFE DA SECRETARIA DE DIREITOS HUMANOS DA PRESIDÊNCIA DA REPÚBLICA']
# FRANCISCO MOREIRA CRUZ FILHO-VICE-PRESIDENTE DO SINDICATO DAS ENTIDADES MANTENEDORAS DOS ESTABELECIMENTOS PARTICULARES DE ENSINO SUPERIOR DO DISTRITO FEDERAL ['FRANCISCO MOREIRA CRUZ FILHO', 'VICE', 'PRESIDENTE DO SINDICATO DAS ENTIDADES MANTENEDORAS DOS ESTABELECIMENTOS PARTICULARES DE ENSINO SUPERIOR DO DISTRITO FEDERAL']
# ROBERTO CARVALHO VELOSO-SECRETÁRIO-GERAL DA ASSOCIAÇÃO DOS JUÍZES FEDERAIS ['ROBERTO CARVALHO VELOSO', 'SECRETÁRIO', 'GERAL DA ASSOCIAÇÃO DOS JUÍZES FEDERAIS']
# PRESIDENTE ['PRESIDENTE']
# MANGABEIRA UNGER (MINISTRO DA SECRETARIA DE ASSUNTOS ESTRATÉGICOS DA PRESIDÊNCIA DA REPÚBLICA) ['MANGABEIRA UNGER (MINISTRO DA SECRETARIA DE ASSUNTOS ESTRATÉGICOS DA PRESIDÊNCIA DA REPÚBLICA)']
# RICARDO LEWANDOWSKI (PRESIDENTE DO SUPREMO TRIBUNAL FEDERAL) ['RICARDO LEWANDOWSKI (PRESIDENTE DO SUPREMO TRIBUNAL FEDERAL)']
# LUIZ CLÁUDIO COSTA ['LUIZ CLÁUDIO COSTA']
# ELIAS MILER DA SILVA ['ELIAS MILER DA SILVA']
# NOEMIA APARECIDA GARCIA PORTO-SECRETÁRIA-GERAL DA ASSOCIAÇÃO NACIONAL DOS MAGISTRADOS DA JUSTIÇA DO TRABALHO ['NOEMIA APARECIDA GARCIA PORTO', 'SECRETÁRIA', 'GERAL DA ASSOCIAÇÃO NACIONAL DOS MAGISTRADOS DA JUSTIÇA DO TRABALHO']
# JUSCILENE CARVALHO (REPRESENTANTE DO CÍRCULO PALMARINO) ['JUSCILENE CARVALHO (REPRESENTANTE DO CÍRCULO PALMARINO)']
# MAURÍCIO DOMINGUES DA SILVA ['MAURÍCIO DOMINGUES DA SILVA']
# ELISEU PADILHA-MINISTRO-CHEFE DA SECRETARIA DE AVIAÇÃO CIVIL DA PRESIDÊNCIA DA REPÚBLICA ['ELISEU PADILHA', 'MINISTRO', 'CHEFE DA SECRETARIA DE AVIAÇÃO CIVIL DA PRESIDÊNCIA DA REPÚBLICA']
# MINISTRO ANTONIO CARLOS RODRIGUES (MINISTRO DOS TRANSPORTES) ['MINISTRO ANTONIO CARLOS RODRIGUES (MINISTRO DOS TRANSPORTES)']
# JUBSON UCHÔA LOPES (SINDICATO DA INDÚSTRIA DA CONSTRUÇÃO CIVIL DO ESTADO DE ALAGOAS - SINDUSCON-AL) ['JUBSON UCHÔA LOPES (SINDICATO DA INDÚSTRIA DA CONSTRUÇÃO CIVIL DO ESTADO DE ALAGOAS ', ' SINDUSCON', 'AL)']
# PEDRO RENATO DE PAULA BRANDÃO (MÉDICO NEUROLOGISTA DA CÂMARA DOS DEPUTADOS) ['PEDRO RENATO DE PAULA BRANDÃO (MÉDICO NEUROLOGISTA DA CÂMARA DOS DEPUTADOS)']
# EDUARDO SAMPAIO MARQUES (REPRESENTANTE DO MINISTÉRIO DA AGRICULTURA, PECUÁRIA E ABASTECIMENTO) [' PECUÁRIA E ABASTECIMENTO)']
# MINISTRO JUCA FERREIRA (MINISTRO DA CULTURA) ['MINISTRO JUCA FERREIRA (MINISTRO DA CULTURA)']
# CID GOMES ['CID GOMES']
# MINISTRO PATRUS ANANIAS (MINISTRO DO DESENVOLVIMENTO AGRÁRIO) ['MINISTRO PATRUS ANANIAS (MINISTRO DO DESENVOLVIMENTO AGRÁRIO)']
# JOSÉ EDUARDO CARDOZO (MINISTRO DA JUSTIÇA) ['JOSÉ EDUARDO CARDOZO (MINISTRO DA JUSTIÇA)']
# MINISTRO JUCA FERREIRA (MINISTRO DA CULTURA) ['MINISTRO JUCA FERREIRA (MINISTRO DA CULTURA)']
# MARIA AUXILIADORA TARGINO DE ARAÚJO ['MARIA AUXILIADORA TARGINO DE ARAÚJO']
# JOÃO FERNANDES DA SILVA- DIRETOR-PRESIDENTE DA AGÊNCIA EXECUTIVA DE GESTÃO DAS ÁGUAS DO ESTADO DA PARAÍBA ['JOÃO FERNANDES DA SILVA', ' DIRETOR', 'PRESIDENTE DA AGÊNCIA EXECUTIVA DE GESTÃO DAS ÁGUAS DO ESTADO DA PARAÍBA']
# ARNALDO JARDIM (SECRETÁRIO DE AGRICULTURA DO GOVERNO DO ESTADO DE SÃO PAULO) ['ARNALDO JARDIM (SECRETÁRIO DE AGRICULTURA DO GOVERNO DO ESTADO DE SÃO PAULO)']
# ELISEU PADILHA-MINISTRO-CHEFE DA SECRETARIA DE AVIAÇÃO CIVIL DA PRESIDÊNCIA DA REPÚBLICA ['ELISEU PADILHA', 'MINISTRO', 'CHEFE DA SECRETARIA DE AVIAÇÃO CIVIL DA PRESIDÊNCIA DA REPÚBLICA']
# HELDER BARBALHO ['HELDER BARBALHO']
# MINISTRO JOAQUIM LEVY (MINISTRO DA FAZENDA) ['MINISTRO JOAQUIM LEVY (MINISTRO DA FAZENDA)']
# LUÍS ANTONIO BOUDENS-VICE-PRESIDENTE DA FEDERAÇÃO NACIONAL DOS POLICIAIS FEDERAIS ['LUÍS ANTONIO BOUDENS', 'VICE', 'PRESIDENTE DA FEDERAÇÃO NACIONAL DOS POLICIAIS FEDERAIS']
# GEORGE HILTON (MINISTRO DO ESPORTE) ['GEORGE HILTON (MINISTRO DO ESPORTE)']
# MINISTRO GILBERTO KASSAB (MINISTRO DAS CIDADES) ['MINISTRO GILBERTO KASSAB (MINISTRO DAS CIDADES)']
# MINISTRO JOAQUIM LEVY (MINISTRO DA FAZENDA) ['MINISTRO JOAQUIM LEVY (MINISTRO DA FAZENDA)']
# CLÁTIA REGINA VIEIRA (COORDENADORA DO FÓRUM NACIONAL DE MULHERES NEGRAS) ['CLÁTIA REGINA VIEIRA (COORDENADORA DO FÓRUM NACIONAL DE MULHERES NEGRAS)']
# ELIZABETH GUEDES-VICE-PRESIDENTE DA ASSOCIAÇÃO NACIONAL DAS UNIVERSIDADES PARTICULARES ['ELIZABETH GUEDES', 'VICE', 'PRESIDENTE DA ASSOCIAÇÃO NACIONAL DAS UNIVERSIDADES PARTICULARES']
# LUIZ NUNES DE OLIVEIRA- PRÓ-REITOR DE PESQUISA DA USP. ['LUIZ NUNES DE OLIVEIRA', ' PRÓ', 'REITOR DE PESQUISA DA USP.']
# JOMAR FERNANDES- 	PREFEITO MUNICIPAL DE IMPERATRIZ, ESTADO DO MARANHÃO; [' ESTADO DO MARANHÃO;']
# MAURÍCIO REBELO (PRESIDENTE) ['MAURÍCIO REBELO (PRESIDENTE)']
# RAFAEL ESMERALDO LUCCHESI RAMACCIOTTI- SECRETÁRIO ESTADUAL DE CIÊNCIA, TECNOLOGIA E INOVAÇÃO DA BAHIA E PRESIDENTE DO FÓRUM NACIONAL DE SECRETÁRIOS ESTADUAIS PARA ASSUNTOS DE CIÊNCIA E TECNOLOGIA. [' TECNOLOGIA E INOVAÇÃO DA BAHIA E PRESIDENTE DO FÓRUM NACIONAL DE SECRETÁRIOS ESTADUAIS PARA ASSUNTOS DE CIÊNCIA E TECNOLOGIA.']
# WAGNER GRANJA VICTER- SECRETÁRIO DE ESTADO DE ENERGIA, DA INDÚSTRIA NAVAL E DO PETRÓLEO DO ESTADO DO RIO DE JANEIRO. [' DA INDÚSTRIA NAVAL E DO PETRÓLEO DO ESTADO DO RIO DE JANEIRO.']
# PIMENTA DA VEIGA-  EX-DEPUTADO FEDERAL ['PIMENTA DA VEIGA', '  EX', 'DEPUTADO FEDERAL']
# DESCARTES TEIXEIRA- DIRETOR-EXECUTIVO DO INSTITUTO DE TECNOLOGIA DE SOFTWARE - ITS. ['DESCARTES TEIXEIRA', ' DIRETOR', 'EXECUTIVO DO INSTITUTO DE TECNOLOGIA DE SOFTWARE ', ' ITS.']
# ROBERTO DE ALENCAR LOTUFO-  DIRETOR-EXECUTIVO DA AGÊNCIA DE INOVAÇÃO DA UNICAMP. ['ROBERTO DE ALENCAR LOTUFO', '  DIRETOR', 'EXECUTIVO DA AGÊNCIA DE INOVAÇÃO DA UNICAMP.']
# ANTÔNIO JOSÉ DANIEL ['ANTÔNIO JOSÉ DANIEL']
# LÍGIA LOPES GOMES ['LÍGIA LOPES GOMES']
# CARLOS VOGT- PRESIDENTE DA FUNDAÇÃO DE AMPARO À PESQUISA DO ESTADO DE SÃO PAULO - FAPESP. ['CARLOS VOGT', ' PRESIDENTE DA FUNDAÇÃO DE AMPARO À PESQUISA DO ESTADO DE SÃO PAULO ', ' FAPESP.']
# ANTÔNIO JOSÉ DANIEL ['ANTÔNIO JOSÉ DANIEL']
# RAQUEL ROLNIK- SECRETÁRIA NACIONAL DE PROGRAMAS URBANOS DO MINISTÉRIO DAS CIDADES, REPRESENTANTE DO MINISTRO OLÍVIO DUTRA [' REPRESENTANTE DO MINISTRO OLÍVIO DUTRA']
# JOÃO PAULO CUNHA (PRESIDENTE) ['JOÃO PAULO CUNHA (PRESIDENTE)']
# MARCOS VINICIUS FERREIRA MAZONI- SECRETÁRIO DE ASSUNTOS ESTRATÉGICOS E PRESIDENTE DA COMPANHIA DE INFORMÁTICA DO PARANÁ - CELEPAR. ['MARCOS VINICIUS FERREIRA MAZONI', ' SECRETÁRIO DE ASSUNTOS ESTRATÉGICOS E PRESIDENTE DA COMPANHIA DE INFORMÁTICA DO PARANÁ ', ' CELEPAR.']
# LUIZ CARLOS RIBEIRO- COORDENADOR-GERAL DE PLANEJAMENTO DA SECRETARIA DE POLÍTICA NACIONAL DE TRANSPORTES, REPRESENTANTE DO SECRETÁRIO JOSÉ AUGUSTO VALENTE. [' REPRESENTANTE DO SECRETÁRIO JOSÉ AUGUSTO VALENTE.']
# ANTONIO FEIJÃO- EX-DEPUTADO FEDERAL, PRESIDENTE DA FUNDAÇÃO INSTITUTO AMAZÔNICO DE MIGRAÇÕES E MEIO AMBIENTE DO ESTADO DO AMAPÁ [' PRESIDENTE DA FUNDAÇÃO INSTITUTO AMAZÔNICO DE MIGRAÇÕES E MEIO AMBIENTE DO ESTADO DO AMAPÁ']
# MARCELO DE CARVALHO LOPES- ASSESSOR ESPECIAL DO MINISTÉRIO DE CIÊNCIA E TECNOLOGIA E SECRETÁRIO-EXECUTIVO DA REDE BRASIL DE TECNOLOGIA. ['MARCELO DE CARVALHO LOPES', ' ASSESSOR ESPECIAL DO MINISTÉRIO DE CIÊNCIA E TECNOLOGIA E SECRETÁRIO', 'EXECUTIVO DA REDE BRASIL DE TECNOLOGIA.']
# SAULO FERREIRA FEITOSA- VICE-PRESIDENTE DO CONSELHO INDIGENISTA MISSIONÁRIO ['SAULO FERREIRA FEITOSA', ' VICE', 'PRESIDENTE DO CONSELHO INDIGENISTA MISSIONÁRIO']
# MÁRIO MOREIRA- PREFEITO MUNICIPAL DE REDENÇÃO, ESTADO DO PARÁ, E PRESIDENTE DA ASSOCIAÇÃO DOS MUNICÍPIOS DO ARAGUAIA E TOCANTINS — AMAT [' ESTADO DO PARÁ']
# SILVESTRE LEOCÁDIO DA SILVA- CACIQUE DA TRIBO MACUXI, PRESIDENTE DA SOCIEDADE DE DEFESA DOS ÍNDIOS UNIDOS DO NORTE DE RORAIMA [' PRESIDENTE DA SOCIEDADE DE DEFESA DOS ÍNDIOS UNIDOS DO NORTE DE RORAIMA']
# MARIA DAS GRAÇAS SILVA FOSTER - SECRETÁRIA DE PETRÓLEO, GÁS NATURAL E COMBUSTÍVEIS RENOVÁVEIS [' GÁS NATURAL E COMBUSTÍVEIS RENOVÁVEIS']
# Finalizado...

# %%
df_plen['ORADOR_CLEAN'] = orador
df_plen['PARTIDO']      = partido
df_plen['UF_PARTIDO']   = ufPartido

# %%
df_plen.SESSION_DATE = df_plen.SESSION_DATE.astype(str)

# %%
df_plen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113143 entries, 0 to 113142
# Data columns (total 13 columns):
# FILE                113143 non-null object
# ORIGINAL_CONTENT    113143 non-null object
# CLEAN_CONTENT       113143 non-null object
# SESSION_TYPE        113143 non-null object
# SESSION_DATE        113143 non-null object
# MONTH               113143 non-null int64
# YEAR                113143 non-null int64
# SPEAKER_COUNT       113143 non-null int64
# Orador              113143 non-null object
# Hora                113143 non-null object
# ORADOR_CLEAN        113143 non-null object
# PARTIDO             113143 non-null object
# UF_PARTIDO          113143 non-null object
# dtypes: int64(3), object(10)
# memory usage: 17.1+ MB

# %%
df_plen.index = [i for i in range(len(df_plen))]
len(df_plen)
# Out:
# 113143

# %%
# Salva
directory = path #"../data/csvs/"
if not os.path.exists(directory):
    os.makedirs(directory)

#name_file = directory + 'discursos_plen.csv'#str(df.YEAR.unique()[0]) + '_plen.csv'
#df_plen.to_csv(name_file, index = False)

name_file = directory + 'discursos_plen.json'#str(df.YEAR.unique()[0]) + '_plen.csv'
df_plen.to_json(name_file)

# %%
df_metadata
d.split(',')
pd.Series(ufPartido).value_counts()
#metadata.loc[int(f):int(f),['Orador','Hora']]

# %%
df_plen.head(10)
#len(df_plen)
#metadata.loc[f:int(f),['Orador','Hora']]

# %%
df_plen.index = [i for i in range(len(df_plen))]
df_plen

# %%
a = pd.DataFrame([1,2,3])
b = pd.DataFrame([10,11,12])

pd.concat([a,b],axis = 1)

# %%
metadata.iloc[0]

# %%
print('Qtd de Registros por ANO:\n{}\n\nQtd Total de registros:{} '.format(df_plen.YEAR.value_counts(),len(df_plen)))

# %%
i = 0
session_date = []
for file in info:
    #print(i)
    result = re.search("\-([A-Z\s]+)\-", file)# info[108251])
    if result is None:
        session_date.append('none')
    else:
        session_date.append(result.group(1))
    #'SESSION_DATE'     : [ re.search("\d{8}", file).group(0) for file in content ]
    i += 1

# %%
len(session_date)
len(info)
